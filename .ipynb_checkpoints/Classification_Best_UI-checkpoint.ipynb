# %%
from sklearn.metrics import classification_report

import keras 
import numpy as np
from keras.preprocessing.text import Tokenizer
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Input, Dense, Dropout, Embedding, LSTM, Flatten
from keras.models import Model
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
plt.style.use('ggplot')
#%matplotlib inline
from IPython.core.display import display, HTML
import logging
import pandas as pd
import numpy as np
from numpy import random
import gensim
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re
from bs4 import BeautifulSoup

from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.externals import joblib


from sklearn.linear_model import SGDClassifier
from sklearn import preprocessing

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

accuracy={}
df = pd.read_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//UI_Def2.csv',delimiter=',',encoding='latin-1')
df= df.dropna()
#df = df[df.Severity.apply(lambda x: x.isnumeric())]
df = df[df.Category.apply(lambda x: x !="")]
df = df[df.Category.apply(lambda x: x !="")]
df.describe()

df.head()



df.Category.value_counts()

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
    return text
    
df['Description'] = df['Description'].apply(clean_text)

le = preprocessing.LabelEncoder()
df['target'] = le.fit_transform(df['Category'])

#df['target'] = df.Category.astype('category').cat.codes


df['num_words'] = df.Description.apply(lambda x : len(x.split()))


bins=[0,50,75, np.inf]
df['bins']=pd.cut(df.num_words, bins=[0,100,300,500,800, np.inf], labels=['0-100', '100-300', '300-500','500-800' ,'>800'])

word_distribution = df.groupby('bins').size().reset_index().rename(columns={0:'counts'})

word_distribution.head()

sns.barplot(x='bins', y='counts', data=word_distribution).set_title("Word distribution per bin")
df.head(10)

num_class = len(np.unique(df.Category.values))
y = df['target'].values

X_train_1, X_test_1, y_train, y_test = train_test_split(df.Description.values, y, test_size=0.3)

# %%
#####RNN###############

MAX_LENGTH = 500
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train_1)
post_seq = tokenizer.texts_to_sequences(X_train_1)
post_seq_padded = pad_sequences(post_seq, maxlen=MAX_LENGTH)

X_train=post_seq_padded

tokenizer.fit_on_texts(X_test_1)
post_seq_test = tokenizer.texts_to_sequences(X_test_1)
post_seq_padded_test = pad_sequences(post_seq_test, maxlen=MAX_LENGTH)

X_test=post_seq_padded_test

#X_train, X_test, y_train, y_test = train_test_split(post_seq_padded, y, test_size=0.3)

vocab_size = len(tokenizer.word_index) + 1


inputs = Input(shape=(MAX_LENGTH, ))
embedding_layer = Embedding(vocab_size,
                            128,
                            input_length=MAX_LENGTH)(inputs)
x = Flatten()(embedding_layer)
x = Dense(32, activation='relu')(x)

predictions = Dense(num_class, activation='softmax')(x)
model = Model(inputs=[inputs], outputs=predictions)
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])


model.summary()
filepath="weights-simple.hdf5"
checkpointer = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
history = model.fit([X_train], batch_size=10, y=to_categorical(y_train), verbose=1, validation_split=0.25, 
          shuffle=True, epochs=100, callbacks=[checkpointer])

#history = model.fit([X_train], batch_size=10, y=y_train, verbose=1, validation_split=0.25, 
 #         shuffle=True, epochs=100, callbacks=[checkpointer])

df1 = pd.DataFrame({'epochs':history.epoch, 'accuracy': history.history['acc'], 'validation_accuracy': history.history['val_acc']})
g = sns.pointplot(x="epochs", y="accuracy", data=df1, fit_reg=False)
g = sns.pointplot(x="epochs", y="validation_accuracy", data=df1, fit_reg=False, color='green')


predicted = model.predict(X_test)
predicted = np.argmax(predicted, axis=1)
accuracy_score(y_test, predicted)
accuracy['RNN']=accuracy_score(y_test, predicted)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,predicted)

predicted = le.inverse_transform(predicted)

pd.DataFrame(cm).to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//RNN_confusion.csv')  

'''print((classification_report(y_test, predicted)))
type(report)
pd.DataFrame(report).to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//RNN_classification.csv')'''

####Reverse dictionary

predictions_human_readable = np.column_stack((X_test_1, predicted))


labelled_data=pd.DataFrame(predictions_human_readable,columns=['Description','Label'])

labelled_data.reset_index().to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//RNN_results.csv')     
#####Pickle the file####
filename = 'C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//RNN_model.sav'
joblib.dump(model, filename)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        (None, 500)               0
# _________________________________________________________________
# embedding_11 (Embedding)     (None, 500, 128)          145024
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 64000)             0
# _________________________________________________________________
# dense_21 (Dense)             (None, 32)                2048032
# _________________________________________________________________
# dense_22 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 2,193,254
# Trainable params: 2,193,254
# Non-trainable params: 0
# _________________________________________________________________
# Train on 51 samples, validate on 18 samples
# Epoch 1/100
# 51/51 [==============================] - 2s 42ms/step - loss: 1.8660 - acc: 0.2941 - val_loss: 1.5785 - val_acc: 0.2778
#
# Epoch 00001: val_acc improved from -inf to 0.27778, saving model to weights-simple.hdf5
# Epoch 2/100
# 51/51 [==============================] - 0s 10ms/step - loss: 1.5773 - acc: 0.4706 - val_loss: 1.4341 - val_acc: 0.2222
#
# Epoch 00002: val_acc did not improve from 0.27778
# Epoch 3/100
# 51/51 [==============================] - 1s 12ms/step - loss: 1.5981 - acc: 0.3333 - val_loss: 1.6286 - val_acc: 0.2778
#
# Epoch 00003: val_acc did not improve from 0.27778
# Epoch 4/100
# 51/51 [==============================] - 1s 12ms/step - loss: 1.4644 - acc: 0.5686 - val_loss: 1.5718 - val_acc: 0.2222
#
# Epoch 00004: val_acc did not improve from 0.27778
# Epoch 5/100
# 51/51 [==============================] - 1s 12ms/step - loss: 1.3411 - acc: 0.4902 - val_loss: 1.5714 - val_acc: 0.2222
#
# Epoch 00005: val_acc did not improve from 0.27778
# Epoch 6/100
# 51/51 [==============================] - 1s 10ms/step - loss: 1.2830 - acc: 0.5686 - val_loss: 1.6192 - val_acc: 0.2222
#
# Epoch 00006: val_acc did not improve from 0.27778
# Epoch 7/100
# 51/51 [==============================] - 1s 12ms/step - loss: 1.1895 - acc: 0.5686 - val_loss: 1.7133 - val_acc: 0.2222
#
# Epoch 00007: val_acc did not improve from 0.27778
# Epoch 8/100
# 51/51 [==============================] - 1s 13ms/step - loss: 1.1742 - acc: 0.4706 - val_loss: 1.7055 - val_acc: 0.2222
#
# Epoch 00008: val_acc did not improve from 0.27778
# Epoch 9/100
# 51/51 [==============================] - 1s 11ms/step - loss: 1.0437 - acc: 0.6275 - val_loss: 1.5863 - val_acc: 0.3333
#
# Epoch 00009: val_acc improved from 0.27778 to 0.33333, saving model to weights-simple.hdf5
# Epoch 10/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.9480 - acc: 0.7451 - val_loss: 1.5471 - val_acc: 0.2222
#
# Epoch 00010: val_acc did not improve from 0.33333
# Epoch 11/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.8430 - acc: 0.7451 - val_loss: 1.5625 - val_acc: 0.2222
#
# Epoch 00011: val_acc did not improve from 0.33333
# Epoch 12/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.7570 - acc: 0.7255 - val_loss: 1.5683 - val_acc: 0.2778
#
# Epoch 00012: val_acc did not improve from 0.33333
# Epoch 13/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.6928 - acc: 0.7843 - val_loss: 1.5468 - val_acc: 0.3333
#
# Epoch 00013: val_acc did not improve from 0.33333
# Epoch 14/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.6167 - acc: 0.8039 - val_loss: 1.5206 - val_acc: 0.3333
#
# Epoch 00014: val_acc did not improve from 0.33333
# Epoch 15/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5625 - acc: 0.8235 - val_loss: 1.5524 - val_acc: 0.3333
#
# Epoch 00015: val_acc did not improve from 0.33333
# Epoch 16/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5173 - acc: 0.8235 - val_loss: 1.5624 - val_acc: 0.3333
#
# Epoch 00016: val_acc did not improve from 0.33333
# Epoch 17/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.4657 - acc: 0.8431 - val_loss: 1.5322 - val_acc: 0.3333
#
# Epoch 00017: val_acc did not improve from 0.33333
# Epoch 18/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4255 - acc: 0.8235 - val_loss: 1.5437 - val_acc: 0.3333
#
# Epoch 00018: val_acc did not improve from 0.33333
# Epoch 19/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3974 - acc: 0.8627 - val_loss: 1.5887 - val_acc: 0.3333
#
# Epoch 00019: val_acc did not improve from 0.33333
# Epoch 20/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.3642 - acc: 0.9216 - val_loss: 1.6131 - val_acc: 0.3333
#
# Epoch 00020: val_acc did not improve from 0.33333
# Epoch 21/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.3341 - acc: 0.9216 - val_loss: 1.6103 - val_acc: 0.3333
#
# Epoch 00021: val_acc did not improve from 0.33333
# Epoch 22/100
# 51/51 [==============================] - ETA: 0s - loss: 0.3103 - acc: 0.920 - 1s 11ms/step - loss: 0.3057 - acc: 0.9216 - val_loss: 1.6143 - val_acc: 0.3333
#
# Epoch 00022: val_acc did not improve from 0.33333
# Epoch 23/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2750 - acc: 0.9216 - val_loss: 1.6725 - val_acc: 0.3333
#
# Epoch 00023: val_acc did not improve from 0.33333
# Epoch 24/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.2569 - acc: 0.9216 - val_loss: 1.6988 - val_acc: 0.3333
#
# Epoch 00024: val_acc did not improve from 0.33333
# Epoch 25/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2325 - acc: 0.9216 - val_loss: 1.6793 - val_acc: 0.3333
#
# Epoch 00025: val_acc did not improve from 0.33333
# Epoch 26/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2164 - acc: 0.9216 - val_loss: 1.6338 - val_acc: 0.3333
#
# Epoch 00026: val_acc did not improve from 0.33333
# Epoch 27/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1949 - acc: 0.9216 - val_loss: 1.6710 - val_acc: 0.3333
#
# Epoch 00027: val_acc did not improve from 0.33333
# Epoch 28/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1778 - acc: 0.9804 - val_loss: 1.7282 - val_acc: 0.3333
#
# Epoch 00028: val_acc did not improve from 0.33333
# Epoch 29/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.1626 - acc: 1.0000 - val_loss: 1.7341 - val_acc: 0.3333
#
# Epoch 00029: val_acc did not improve from 0.33333
# Epoch 30/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.1535 - acc: 1.0000 - val_loss: 1.7576 - val_acc: 0.3333
#
# Epoch 00030: val_acc did not improve from 0.33333
# Epoch 31/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.1533 - acc: 1.0000 - val_loss: 1.7608 - val_acc: 0.3889
#
# Epoch 00031: val_acc improved from 0.33333 to 0.38889, saving model to weights-simple.hdf5
# Epoch 32/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.1294 - acc: 1.0000 - val_loss: 1.8250 - val_acc: 0.3333
#
# Epoch 00032: val_acc did not improve from 0.38889
# Epoch 33/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.1032 - acc: 1.0000 - val_loss: 1.7961 - val_acc: 0.3333
#
# Epoch 00033: val_acc did not improve from 0.38889
# Epoch 34/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0992 - acc: 1.0000 - val_loss: 1.7633 - val_acc: 0.3333
#
# Epoch 00034: val_acc did not improve from 0.38889
# Epoch 35/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0832 - acc: 1.0000 - val_loss: 1.6637 - val_acc: 0.3333
#
# Epoch 00035: val_acc did not improve from 0.38889
# Epoch 36/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0710 - acc: 1.0000 - val_loss: 1.6768 - val_acc: 0.4444
#
# Epoch 00036: val_acc improved from 0.38889 to 0.44444, saving model to weights-simple.hdf5
# Epoch 37/100
# 51/51 [==============================] - 0s 10ms/step - loss: 0.0631 - acc: 1.0000 - val_loss: 1.7417 - val_acc: 0.3333
#
# Epoch 00037: val_acc did not improve from 0.44444
# Epoch 38/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0576 - acc: 1.0000 - val_loss: 1.8839 - val_acc: 0.3333
#
# Epoch 00038: val_acc did not improve from 0.44444
# Epoch 39/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0525 - acc: 1.0000 - val_loss: 1.9431 - val_acc: 0.3333
#
# Epoch 00039: val_acc did not improve from 0.44444
# Epoch 40/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0482 - acc: 1.0000 - val_loss: 1.9324 - val_acc: 0.3333
#
# Epoch 00040: val_acc did not improve from 0.44444
# Epoch 41/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0430 - acc: 1.0000 - val_loss: 1.8842 - val_acc: 0.3333
#
# Epoch 00041: val_acc did not improve from 0.44444
# Epoch 42/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0392 - acc: 1.0000 - val_loss: 1.8504 - val_acc: 0.3889
#
# Epoch 00042: val_acc did not improve from 0.44444
# Epoch 43/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0360 - acc: 1.0000 - val_loss: 1.8120 - val_acc: 0.3889
#
# Epoch 00043: val_acc did not improve from 0.44444
# Epoch 44/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0335 - acc: 1.0000 - val_loss: 1.8170 - val_acc: 0.3889
#
# Epoch 00044: val_acc did not improve from 0.44444
# Epoch 45/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0309 - acc: 1.0000 - val_loss: 1.8335 - val_acc: 0.3889
#
# Epoch 00045: val_acc did not improve from 0.44444
# Epoch 46/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0285 - acc: 1.0000 - val_loss: 1.8546 - val_acc: 0.3889
#
# Epoch 00046: val_acc did not improve from 0.44444
# Epoch 47/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0266 - acc: 1.0000 - val_loss: 1.9006 - val_acc: 0.3889
#
# Epoch 00047: val_acc did not improve from 0.44444
# Epoch 48/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0248 - acc: 1.0000 - val_loss: 1.9154 - val_acc: 0.3333
#
# Epoch 00048: val_acc did not improve from 0.44444
# Epoch 49/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0234 - acc: 1.0000 - val_loss: 1.9342 - val_acc: 0.3889
#
# Epoch 00049: val_acc did not improve from 0.44444
# Epoch 50/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0212 - acc: 1.0000 - val_loss: 1.9787 - val_acc: 0.3889
#
# Epoch 00050: val_acc did not improve from 0.44444
# Epoch 51/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0212 - acc: 1.0000 - val_loss: 2.0159 - val_acc: 0.3889
#
# Epoch 00051: val_acc did not improve from 0.44444
# Epoch 52/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0191 - acc: 1.0000 - val_loss: 1.9172 - val_acc: 0.3889
#
# Epoch 00052: val_acc did not improve from 0.44444
# Epoch 53/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0181 - acc: 1.0000 - val_loss: 1.8288 - val_acc: 0.3889
#
# Epoch 00053: val_acc did not improve from 0.44444
# Epoch 54/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0166 - acc: 1.0000 - val_loss: 1.8239 - val_acc: 0.3889
#
# Epoch 00054: val_acc did not improve from 0.44444
# Epoch 55/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0152 - acc: 1.0000 - val_loss: 1.8627 - val_acc: 0.3889
#
# Epoch 00055: val_acc did not improve from 0.44444
# Epoch 56/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0143 - acc: 1.0000 - val_loss: 1.9124 - val_acc: 0.3889
#
# Epoch 00056: val_acc did not improve from 0.44444
# Epoch 57/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0135 - acc: 1.0000 - val_loss: 1.9782 - val_acc: 0.3889
#
# Epoch 00057: val_acc did not improve from 0.44444
# Epoch 58/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0126 - acc: 1.0000 - val_loss: 2.0475 - val_acc: 0.3333
#
# Epoch 00058: val_acc did not improve from 0.44444
# Epoch 59/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0117 - acc: 1.0000 - val_loss: 2.0862 - val_acc: 0.3333
#
# Epoch 00059: val_acc did not improve from 0.44444
# Epoch 60/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0113 - acc: 1.0000 - val_loss: 2.1096 - val_acc: 0.3889
#
# Epoch 00060: val_acc did not improve from 0.44444
# Epoch 61/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0110 - acc: 1.0000 - val_loss: 2.1152 - val_acc: 0.3889
#
# Epoch 00061: val_acc did not improve from 0.44444
# Epoch 62/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0108 - acc: 1.0000 - val_loss: 2.1250 - val_acc: 0.3889
#
# Epoch 00062: val_acc did not improve from 0.44444
# Epoch 63/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0102 - acc: 1.0000 - val_loss: 2.0930 - val_acc: 0.3333
#
# Epoch 00063: val_acc did not improve from 0.44444
# Epoch 64/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0094 - acc: 1.0000 - val_loss: 2.0345 - val_acc: 0.3333
#
# Epoch 00064: val_acc did not improve from 0.44444
# Epoch 65/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0091 - acc: 1.0000 - val_loss: 2.0278 - val_acc: 0.3333
#
# Epoch 00065: val_acc did not improve from 0.44444
# Epoch 66/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0083 - acc: 1.0000 - val_loss: 2.0923 - val_acc: 0.3889
#
# Epoch 00066: val_acc did not improve from 0.44444
# Epoch 67/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0079 - acc: 1.0000 - val_loss: 2.1156 - val_acc: 0.3889
#
# Epoch 00067: val_acc did not improve from 0.44444
# Epoch 68/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0076 - acc: 1.0000 - val_loss: 2.1396 - val_acc: 0.3889
#
# Epoch 00068: val_acc did not improve from 0.44444
# Epoch 69/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0072 - acc: 1.0000 - val_loss: 2.1460 - val_acc: 0.3889
#
# Epoch 00069: val_acc did not improve from 0.44444
# Epoch 70/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0067 - acc: 1.0000 - val_loss: 2.1331 - val_acc: 0.3889
#
# Epoch 00070: val_acc did not improve from 0.44444
# Epoch 71/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0065 - acc: 1.0000 - val_loss: 2.1224 - val_acc: 0.3889
#
# Epoch 00071: val_acc did not improve from 0.44444
# Epoch 72/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0063 - acc: 1.0000 - val_loss: 2.1046 - val_acc: 0.3889
#
# Epoch 00072: val_acc did not improve from 0.44444
# Epoch 73/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0061 - acc: 1.0000 - val_loss: 2.1023 - val_acc: 0.3889
#
# Epoch 00073: val_acc did not improve from 0.44444
# Epoch 74/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0059 - acc: 1.0000 - val_loss: 2.1133 - val_acc: 0.3889
#
# Epoch 00074: val_acc did not improve from 0.44444
# Epoch 75/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0057 - acc: 1.0000 - val_loss: 2.1236 - val_acc: 0.3889
#
# Epoch 00075: val_acc did not improve from 0.44444
# Epoch 76/100
# 51/51 [==============================] - 1s 14ms/step - loss: 0.0055 - acc: 1.0000 - val_loss: 2.1294 - val_acc: 0.3889
#
# Epoch 00076: val_acc did not improve from 0.44444
# Epoch 77/100
# 51/51 [==============================] - 1s 13ms/step - loss: 0.0053 - acc: 1.0000 - val_loss: 2.1290 - val_acc: 0.3889
#
# Epoch 00077: val_acc did not improve from 0.44444
# Epoch 78/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0051 - acc: 1.0000 - val_loss: 2.1231 - val_acc: 0.3889
#
# Epoch 00078: val_acc did not improve from 0.44444
# Epoch 79/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0050 - acc: 1.0000 - val_loss: 2.1008 - val_acc: 0.3889
#
# Epoch 00079: val_acc did not improve from 0.44444
# Epoch 80/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0048 - acc: 1.0000 - val_loss: 2.0963 - val_acc: 0.3889
#
# Epoch 00080: val_acc did not improve from 0.44444
# Epoch 81/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0047 - acc: 1.0000 - val_loss: 2.1029 - val_acc: 0.3889
#
# Epoch 00081: val_acc did not improve from 0.44444
# Epoch 82/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0046 - acc: 1.0000 - val_loss: 2.1105 - val_acc: 0.3889
#
# Epoch 00082: val_acc did not improve from 0.44444
# Epoch 83/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0045 - acc: 1.0000 - val_loss: 2.1235 - val_acc: 0.3889
# Epoch 00083: val_acc did not improve from 0.44444
# Epoch 84/100
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0043 - acc: 1.0000 - val_loss: 2.1396 - val_acc: 0.3889
#
# Epoch 00084: val_acc did not improve from 0.44444
# Epoch 85/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0042 - acc: 1.0000 - val_loss: 2.1438 - val_acc: 0.3889
#
# Epoch 00085: val_acc did not improve from 0.44444
# Epoch 86/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0041 - acc: 1.0000 - val_loss: 2.1409 - val_acc: 0.3889
#
# Epoch 00086: val_acc did not improve from 0.44444
# Epoch 87/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0040 - acc: 1.0000 - val_loss: 2.1445 - val_acc: 0.3889
#
# Epoch 00087: val_acc did not improve from 0.44444
# Epoch 88/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0039 - acc: 1.0000 - val_loss: 2.1533 - val_acc: 0.3889
#
# Epoch 00088: val_acc did not improve from 0.44444
# Epoch 89/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0038 - acc: 1.0000 - val_loss: 2.1595 - val_acc: 0.3889
#
# Epoch 00089: val_acc did not improve from 0.44444
# Epoch 90/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0038 - acc: 1.0000 - val_loss: 2.1633 - val_acc: 0.3889
#
# Epoch 00090: val_acc did not improve from 0.44444
# Epoch 91/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0037 - acc: 1.0000 - val_loss: 2.1575 - val_acc: 0.3889
#
# Epoch 00091: val_acc did not improve from 0.44444
# Epoch 92/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0035 - acc: 1.0000 - val_loss: 2.1610 - val_acc: 0.3889
#
# Epoch 00092: val_acc did not improve from 0.44444
# Epoch 93/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0034 - acc: 1.0000 - val_loss: 2.1671 - val_acc: 0.3889
#
# Epoch 00093: val_acc did not improve from 0.44444
# Epoch 94/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0033 - acc: 1.0000 - val_loss: 2.1680 - val_acc: 0.3889
#
# Epoch 00094: val_acc did not improve from 0.44444
# Epoch 95/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0032 - acc: 1.0000 - val_loss: 2.1598 - val_acc: 0.3889
#
# Epoch 00095: val_acc did not improve from 0.44444
# Epoch 96/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0031 - acc: 1.0000 - val_loss: 2.1643 - val_acc: 0.3889
#
# Epoch 00096: val_acc did not improve from 0.44444
# Epoch 97/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0031 - acc: 1.0000 - val_loss: 2.1705 - val_acc: 0.3889
#
# Epoch 00097: val_acc did not improve from 0.44444
# Epoch 98/100
# 51/51 [==============================] - 1s 10ms/step - loss: 0.0030 - acc: 1.0000 - val_loss: 2.1806 - val_acc: 0.3889
#
# Epoch 00098: val_acc did not improve from 0.44444
# Epoch 99/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 2.1880 - val_acc: 0.3889
#
# Epoch 00099: val_acc did not improve from 0.44444
# Epoch 100/100
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0028 - acc: 1.0000 - val_loss: 2.1894 - val_acc: 0.3889
#
# Epoch 00100: val_acc did not improve from 0.44444
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ['C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//RNN_model.sav']

# %%
##############################SVM##########################

sgd = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=15, tol=None)),
               ])
sgd.fit(X_train_1, y_train)


y_pred = sgd.predict(X_test_1)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred))

accuracy['SVM']=accuracy_score(y_test, y_pred)



print(classification_report(y_test, y_pred))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)

y_pred = le.inverse_transform(y_pred)
predictions_file = np.column_stack((X_test_1, y_pred))

pd.DataFrame(cm).to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//SVM_confusion.csv')  

'''pd.DataFrame(classification_report(y_test, predicted)).to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//SVM_classification.csv')'''  


labelled_data_SVM=pd.DataFrame(predictions_file,columns=['Description','Label'])
labelled_data_SVM.reset_index().to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//SVM_results.csv')     
#####Pickle the file####
filename = 'C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//SVM_model.sav'
joblib.dump(sgd, filename)
# Out:
# accuracy 0.4666666666666667
#              precision    recall  f1-score   support
#
#           1       0.36      0.50      0.42         8
#           2       0.45      0.62      0.53         8
#           3       0.67      1.00      0.80         4
#           4       0.00      0.00      0.00         5
#           5       0.50      0.20      0.29         5
#
# avg / total       0.39      0.47      0.41        30
#
#              precision    recall  f1-score   support
#
#           1       0.36      0.50      0.42         8
#           2       0.45      0.62      0.53         8
#           3       0.67      1.00      0.80         4
#           4       0.00      0.00      0.00         5
#           5       0.50      0.20      0.29         5
#
# avg / total       0.39      0.47      0.41        30
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ['C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//SVM_model.sav']

# %%
##################LSTM####################

inputs = Input(shape=(MAX_LENGTH, ))
embedding_layer = Embedding(vocab_size,
                            128,
                            input_length=MAX_LENGTH)(inputs)

x = LSTM(64)(embedding_layer)
x = Dense(32, activation='relu')(x)
predictions = Dense(num_class, activation='softmax')(x)
model = Model(inputs=[inputs], outputs=predictions)
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])

model.summary()


filepath="weights.hdf5"
checkpointer = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
history = model.fit([X_train], batch_size=50, y=to_categorical(y_train), verbose=1, validation_split=0.25, 
          shuffle=True, epochs=100, callbacks=[checkpointer])


df2 = pd.DataFrame({'epochs':history.epoch, 'accuracy': history.history['acc'], 'validation_accuracy': history.history['val_acc']})
g = sns.pointplot(x="epochs", y="accuracy", data=df2, fit_reg=False)
g = sns.pointplot(x="epochs", y="validation_accuracy", data=df2, fit_reg=False, color='green')



model.load_weights('weights.hdf5')
predicted = model.predict(X_test)

predicted = np.argmax(predicted, axis=1)

accuracy_score(y_test, predicted)
accuracy['LSTM']=accuracy_score(y_test, predicted)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,predicted)
pd.DataFrame(cm).to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//LSTM_confusion.csv')  


'''print(classification_report(y_test, predicted))

pd.DataFrame(classification_report(y_test, predicted)).to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//LSTM_classification.csv')  '''

####Reverse dictionary

predicted = le.inverse_transform(predicted)
predictions_human_readable = np.column_stack((X_test_1, predicted))



labelled_data=pd.DataFrame(predictions_human_readable,columns=['Description','Label'])
labelled_data.reset_index().to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//LSTM_results.csv')     
#####Pickle the file####
filename = 'C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//LSTM_model.sav'
joblib.dump(model, filename)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_12 (InputLayer)        (None, 500)               0
# _________________________________________________________________
# embedding_12 (Embedding)     (None, 500, 128)          145024
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense_23 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_24 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 196,710
# Trainable params: 196,710
# Non-trainable params: 0
# _________________________________________________________________
# Train on 51 samples, validate on 18 samples
# Epoch 1/100
# 51/51 [==============================] - 2s 42ms/step - loss: 1.7908 - acc: 0.1961 - val_loss: 1.7882 - val_acc: 0.2222
#
# Epoch 00001: val_acc improved from -inf to 0.22222, saving model to weights.hdf5
# Epoch 2/100
# 51/51 [==============================] - 1s 15ms/step - loss: 1.7776 - acc: 0.5882 - val_loss: 1.7868 - val_acc: 0.2778
#
# Epoch 00002: val_acc improved from 0.22222 to 0.27778, saving model to weights.hdf5
# Epoch 3/100
# 51/51 [==============================] - 1s 15ms/step - loss: 1.7696 - acc: 0.6667 - val_loss: 1.7848 - val_acc: 0.2778
#
# Epoch 00003: val_acc did not improve from 0.27778
# Epoch 4/100
# 51/51 [==============================] - 1s 20ms/step - loss: 1.7611 - acc: 0.7255 - val_loss: 1.7827 - val_acc: 0.2778
#
# Epoch 00004: val_acc did not improve from 0.27778
# Epoch 5/100
# 51/51 [==============================] - 2s 37ms/step - loss: 1.7507 - acc: 0.6471 - val_loss: 1.7800 - val_acc: 0.2778
#
# Epoch 00005: val_acc did not improve from 0.27778
# Epoch 6/100
# 51/51 [==============================] - 2s 30ms/step - loss: 1.7383 - acc: 0.6667 - val_loss: 1.7766 - val_acc: 0.2778
#
# Epoch 00006: val_acc did not improve from 0.27778
# Epoch 7/100
# 51/51 [==============================] - 1s 24ms/step - loss: 1.7247 - acc: 0.6667 - val_loss: 1.7726 - val_acc: 0.2778
#
# Epoch 00007: val_acc did not improve from 0.27778
# Epoch 8/100
# 51/51 [==============================] - 1s 18ms/step - loss: 1.7090 - acc: 0.6275 - val_loss: 1.7692 - val_acc: 0.2778
#
# Epoch 00008: val_acc did not improve from 0.27778
# Epoch 9/100
# 51/51 [==============================] - 1s 17ms/step - loss: 1.6906 - acc: 0.6275 - val_loss: 1.7662 - val_acc: 0.2222
#
# Epoch 00009: val_acc did not improve from 0.27778
# Epoch 10/100
# 51/51 [==============================] - 1s 18ms/step - loss: 1.6696 - acc: 0.6078 - val_loss: 1.7631 - val_acc: 0.2222
#
# Epoch 00010: val_acc did not improve from 0.27778
# Epoch 11/100
# 51/51 [==============================] - 1s 22ms/step - loss: 1.6432 - acc: 0.5490 - val_loss: 1.7603 - val_acc: 0.2222
#
# Epoch 00011: val_acc did not improve from 0.27778
# Epoch 12/100
# 51/51 [==============================] - 1s 20ms/step - loss: 1.6130 - acc: 0.5098 - val_loss: 1.7572 - val_acc: 0.2222
#
# Epoch 00012: val_acc did not improve from 0.27778
# Epoch 13/100
# 51/51 [==============================] - 1s 17ms/step - loss: 1.5772 - acc: 0.5098 - val_loss: 1.7533 - val_acc: 0.2222
#
# Epoch 00013: val_acc did not improve from 0.27778
# Epoch 14/100
# 51/51 [==============================] - 1s 15ms/step - loss: 1.5333 - acc: 0.5098 - val_loss: 1.7496 - val_acc: 0.2222
#
# Epoch 00014: val_acc did not improve from 0.27778
# Epoch 15/100
# 51/51 [==============================] - 1s 15ms/step - loss: 1.4737 - acc: 0.5294 - val_loss: 1.7502 - val_acc: 0.2222
#
# Epoch 00015: val_acc did not improve from 0.27778
# Epoch 16/100
# 51/51 [==============================] - 1s 17ms/step - loss: 1.3860 - acc: 0.4902 - val_loss: 1.8114 - val_acc: 0.2222
#
# Epoch 00016: val_acc did not improve from 0.27778
# Epoch 17/100
# 51/51 [==============================] - 1s 17ms/step - loss: 1.2835 - acc: 0.4510 - val_loss: 1.9000 - val_acc: 0.2222
#
# Epoch 00017: val_acc did not improve from 0.27778
# Epoch 18/100
# 51/51 [==============================] - 1s 18ms/step - loss: 1.2433 - acc: 0.4510 - val_loss: 1.7661 - val_acc: 0.2222
#
# Epoch 00018: val_acc did not improve from 0.27778
# Epoch 19/100
# 51/51 [==============================] - 1s 18ms/step - loss: 1.1969 - acc: 0.5098 - val_loss: 1.7286 - val_acc: 0.2222
#
# Epoch 00019: val_acc did not improve from 0.27778
# Epoch 20/100
# 51/51 [==============================] - 1s 21ms/step - loss: 1.1692 - acc: 0.5294 - val_loss: 1.7317 - val_acc: 0.2222
#
# Epoch 00020: val_acc did not improve from 0.27778
# Epoch 21/100
# 51/51 [==============================] - 1s 22ms/step - loss: 1.1226 - acc: 0.5294 - val_loss: 1.7842 - val_acc: 0.2222
#
# Epoch 00021: val_acc did not improve from 0.27778
# Epoch 22/100
# 51/51 [==============================] - 1s 25ms/step - loss: 1.0843 - acc: 0.5294 - val_loss: 1.7880 - val_acc: 0.2222
#
# Epoch 00022: val_acc did not improve from 0.27778
# Epoch 23/100
# 51/51 [==============================] - 2s 31ms/step - loss: 1.0446 - acc: 0.5686 - val_loss: 1.6887 - val_acc: 0.2778
#
# Epoch 00023: val_acc did not improve from 0.27778
# Epoch 24/100
# 51/51 [==============================] - 2s 44ms/step - loss: 1.0142 - acc: 0.6275 - val_loss: 1.6449 - val_acc: 0.2778
#
# Epoch 00024: val_acc did not improve from 0.27778
# Epoch 25/100
# 51/51 [==============================] - 1s 28ms/step - loss: 1.0077 - acc: 0.7255 - val_loss: 1.6327 - val_acc: 0.3333
#
# Epoch 00025: val_acc improved from 0.27778 to 0.33333, saving model to weights.hdf5
# Epoch 26/100
# 51/51 [==============================] - 1s 23ms/step - loss: 0.9922 - acc: 0.7647 - val_loss: 1.6265 - val_acc: 0.3333
#
# Epoch 00026: val_acc did not improve from 0.33333
# Epoch 27/100
# 51/51 [==============================] - 1s 24ms/step - loss: 0.9676 - acc: 0.7647 - val_loss: 1.6243 - val_acc: 0.3333
#
# Epoch 00027: val_acc did not improve from 0.33333
# Epoch 28/100
# 51/51 [==============================] - 1s 20ms/step - loss: 0.9396 - acc: 0.7451 - val_loss: 1.6281 - val_acc: 0.3333
#
# Epoch 00028: val_acc did not improve from 0.33333
# Epoch 29/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.9085 - acc: 0.7451 - val_loss: 1.6358 - val_acc: 0.3333
#
# Epoch 00029: val_acc did not improve from 0.33333
# Epoch 30/100
# 51/51 [==============================] - 1s 18ms/step - loss: 0.8766 - acc: 0.7647 - val_loss: 1.6593 - val_acc: 0.3333
#
# Epoch 00030: val_acc did not improve from 0.33333
# Epoch 31/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.8447 - acc: 0.7451 - val_loss: 1.7257 - val_acc: 0.3333
#
# Epoch 00031: val_acc did not improve from 0.33333
# Epoch 32/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.8195 - acc: 0.7255 - val_loss: 1.8332 - val_acc: 0.3333
#
# Epoch 00032: val_acc did not improve from 0.33333
# Epoch 33/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.8015 - acc: 0.7255 - val_loss: 1.9176 - val_acc: 0.3333
#
# Epoch 00033: val_acc did not improve from 0.33333
# Epoch 34/100
# 51/51 [==============================] - 1s 21ms/step - loss: 0.7754 - acc: 0.7059 - val_loss: 1.9333 - val_acc: 0.3333
#
# Epoch 00034: val_acc did not improve from 0.33333
# Epoch 35/100
# 51/51 [==============================] - 1s 21ms/step - loss: 0.7368 - acc: 0.7647 - val_loss: 1.9064 - val_acc: 0.3333
#
# Epoch 00035: val_acc did not improve from 0.33333
# Epoch 36/100
# 51/51 [==============================] - 1s 18ms/step - loss: 0.7023 - acc: 0.8039 - val_loss: 1.8806 - val_acc: 0.3333
#
# Epoch 00036: val_acc did not improve from 0.33333
# Epoch 37/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.6738 - acc: 0.9020 - val_loss: 1.8385 - val_acc: 0.3889
#
# Epoch 00037: val_acc improved from 0.33333 to 0.38889, saving model to weights.hdf5
# Epoch 38/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.6478 - acc: 0.9216 - val_loss: 2.0036 - val_acc: 0.3889
#
# Epoch 00038: val_acc did not improve from 0.38889
# Epoch 39/100
# 51/51 [==============================] - 1s 21ms/step - loss: 0.5904 - acc: 0.9608 - val_loss: 2.6498 - val_acc: 0.2778
#
# Epoch 00039: val_acc did not improve from 0.38889
# Epoch 40/100
# 51/51 [==============================] - 1s 24ms/step - loss: 0.6672 - acc: 0.8431 - val_loss: 2.1210 - val_acc: 0.5000
#
# Epoch 00040: val_acc improved from 0.38889 to 0.50000, saving model to weights.hdf5
# Epoch 41/100
# 51/51 [==============================] - 1s 22ms/step - loss: 0.5405 - acc: 0.9412 - val_loss: 1.9524 - val_acc: 0.4444
#
# Epoch 00041: val_acc did not improve from 0.50000
# Epoch 42/100
# 51/51 [==============================] - 1s 18ms/step - loss: 0.5261 - acc: 0.9804 - val_loss: 1.9150 - val_acc: 0.4444
#
# Epoch 00042: val_acc did not improve from 0.50000
# Epoch 43/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.4951 - acc: 0.9804 - val_loss: 1.8479 - val_acc: 0.5000
#
# Epoch 00043: val_acc did not improve from 0.50000
# Epoch 44/100
# 51/51 [==============================] - 1s 18ms/step - loss: 0.4784 - acc: 0.9804 - val_loss: 1.7690 - val_acc: 0.4444
#
# Epoch 00044: val_acc did not improve from 0.50000
# Epoch 45/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.4774 - acc: 0.9804 - val_loss: 1.6527 - val_acc: 0.4444
#
# Epoch 00045: val_acc did not improve from 0.50000
# Epoch 46/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.5676 - acc: 0.9216 - val_loss: 1.6024 - val_acc: 0.4444
#
# Epoch 00046: val_acc did not improve from 0.50000
# Epoch 47/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.6177 - acc: 0.8627 - val_loss: 1.5701 - val_acc: 0.5000
#
# Epoch 00047: val_acc did not improve from 0.50000
# Epoch 48/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.5825 - acc: 0.8824 - val_loss: 1.5541 - val_acc: 0.5000
#
# Epoch 00048: val_acc did not improve from 0.50000
# Epoch 49/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.5123 - acc: 0.9412 - val_loss: 1.5527 - val_acc: 0.4444
#
# Epoch 00049: val_acc did not improve from 0.50000
# Epoch 50/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.4343 - acc: 0.9412 - val_loss: 1.5546 - val_acc: 0.4444
#
# Epoch 00050: val_acc did not improve from 0.50000
# Epoch 51/100
# 51/51 [==============================] - 1s 21ms/step - loss: 0.3670 - acc: 0.9804 - val_loss: 1.5727 - val_acc: 0.3889
#
# Epoch 00051: val_acc did not improve from 0.50000
# Epoch 52/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.3294 - acc: 0.9804 - val_loss: 1.6198 - val_acc: 0.5000
#
# Epoch 00052: val_acc did not improve from 0.50000
# Epoch 53/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.3127 - acc: 0.9804 - val_loss: 1.6992 - val_acc: 0.5000
#
# Epoch 00053: val_acc did not improve from 0.50000
# Epoch 54/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.3037 - acc: 0.9804 - val_loss: 1.7705 - val_acc: 0.4444
#
# Epoch 00054: val_acc did not improve from 0.50000
# Epoch 55/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.2943 - acc: 0.9804 - val_loss: 1.8137 - val_acc: 0.4444
#
# Epoch 00055: val_acc did not improve from 0.50000
# Epoch 56/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.2811 - acc: 0.9804 - val_loss: 1.8354 - val_acc: 0.4444
#
# Epoch 00056: val_acc did not improve from 0.50000
# Epoch 57/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.2670 - acc: 0.9804 - val_loss: 1.8348 - val_acc: 0.4444
#
# Epoch 00057: val_acc did not improve from 0.50000
# Epoch 58/100
# 51/51 [==============================] - 1s 18ms/step - loss: 0.2516 - acc: 0.9804 - val_loss: 1.8175 - val_acc: 0.4444
#
# Epoch 00058: val_acc did not improve from 0.50000
# Epoch 59/100
# 51/51 [==============================] - 1s 20ms/step - loss: 0.2347 - acc: 0.9804 - val_loss: 1.7874 - val_acc: 0.4444
#
# Epoch 00059: val_acc did not improve from 0.50000
# Epoch 60/100
# 51/51 [==============================] - 1s 18ms/step - loss: 0.2178 - acc: 0.9804 - val_loss: 1.7490 - val_acc: 0.4444
#
# Epoch 00060: val_acc did not improve from 0.50000
# Epoch 61/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.2026 - acc: 0.9804 - val_loss: 1.7102 - val_acc: 0.4444
#
# Epoch 00061: val_acc did not improve from 0.50000
# Epoch 62/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.1888 - acc: 0.9804 - val_loss: 1.6761 - val_acc: 0.4444
#
# Epoch 00062: val_acc did not improve from 0.50000
# Epoch 63/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.1763 - acc: 0.9804 - val_loss: 1.6653 - val_acc: 0.5000
#
# Epoch 00063: val_acc did not improve from 0.50000
# Epoch 64/100
# 51/51 [==============================] - 1s 20ms/step - loss: 0.1644 - acc: 0.9804 - val_loss: 1.6757 - val_acc: 0.5000
#
# Epoch 00064: val_acc did not improve from 0.50000
# Epoch 65/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.1537 - acc: 0.9804 - val_loss: 1.7087 - val_acc: 0.5000
#
# Epoch 00065: val_acc did not improve from 0.50000
# Epoch 66/100
# 51/51 [==============================] - 1s 20ms/step - loss: 0.1444 - acc: 0.9804 - val_loss: 1.7663 - val_acc: 0.5000
#
# Epoch 00066: val_acc did not improve from 0.50000
# Epoch 67/100
# 51/51 [==============================] - 1s 18ms/step - loss: 0.1370 - acc: 1.0000 - val_loss: 1.8096 - val_acc: 0.5000
#
# Epoch 00067: val_acc did not improve from 0.50000
# Epoch 68/100
# 51/51 [==============================] - 1s 22ms/step - loss: 0.1315 - acc: 1.0000 - val_loss: 1.7270 - val_acc: 0.5000
#
# Epoch 00068: val_acc did not improve from 0.50000
# Epoch 69/100
# 51/51 [==============================] - 1s 20ms/step - loss: 0.1221 - acc: 1.0000 - val_loss: 1.6236 - val_acc: 0.5000
#
# Epoch 00069: val_acc did not improve from 0.50000
# Epoch 70/100
# 51/51 [==============================] - 1s 18ms/step - loss: 0.1151 - acc: 1.0000 - val_loss: 1.5948 - val_acc: 0.5000
#
# Epoch 00070: val_acc did not improve from 0.50000
# Epoch 71/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.1108 - acc: 1.0000 - val_loss: 1.5596 - val_acc: 0.5000
#
# Epoch 00071: val_acc did not improve from 0.50000
# Epoch 72/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.1032 - acc: 1.0000 - val_loss: 1.4668 - val_acc: 0.5556
#
# Epoch 00072: val_acc improved from 0.50000 to 0.55556, saving model to weights.hdf5
# Epoch 73/100
# 51/51 [==============================] - 1s 18ms/step - loss: 0.0951 - acc: 1.0000 - val_loss: 1.4197 - val_acc: 0.6111
#
# Epoch 00073: val_acc improved from 0.55556 to 0.61111, saving model to weights.hdf5
# Epoch 74/100
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0925 - acc: 1.0000 - val_loss: 1.4245 - val_acc: 0.6667
#
# Epoch 00074: val_acc improved from 0.61111 to 0.66667, saving model to weights.hdf5
# Epoch 75/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.0936 - acc: 1.0000 - val_loss: 1.4502 - val_acc: 0.6667
#
# Epoch 00075: val_acc did not improve from 0.66667
# Epoch 76/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.0927 - acc: 1.0000 - val_loss: 1.4785 - val_acc: 0.6667
#
# Epoch 00076: val_acc did not improve from 0.66667
# Epoch 77/100
# 51/51 [==============================] - 1s 22ms/step - loss: 0.0881 - acc: 1.0000 - val_loss: 1.5108 - val_acc: 0.6667
#
# Epoch 00077: val_acc did not improve from 0.66667
# Epoch 78/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.0792 - acc: 1.0000 - val_loss: 1.5675 - val_acc: 0.5556
#
# Epoch 00078: val_acc did not improve from 0.66667
# Epoch 79/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.0700 - acc: 1.0000 - val_loss: 1.6516 - val_acc: 0.5000
#
# Epoch 00079: val_acc did not improve from 0.66667
# Epoch 80/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.0638 - acc: 1.0000 - val_loss: 1.5834 - val_acc: 0.5556
#
# Epoch 00080: val_acc did not improve from 0.66667
# Epoch 81/100
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0600 - acc: 1.0000 - val_loss: 1.5166 - val_acc: 0.5556
#
# Epoch 00081: val_acc did not improve from 0.66667
# Epoch 82/100
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0626 - acc: 1.0000 - val_loss: 1.5059 - val_acc: 0.5556
#
# Epoch 00082: val_acc did not improve from 0.66667
# Epoch 83/100
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0652 - acc: 1.0000 - val_loss: 1.5105 - val_acc: 0.5556
#
# Epoch 00083: val_acc did not improve from 0.66667
# Epoch 84/100
# 51/51 [==============================] - 1s 22ms/step - loss: 0.0649 - acc: 1.0000 - val_loss: 1.5197 - val_acc: 0.5556
#
# Epoch 00084: val_acc did not improve from 0.66667
# Epoch 85/100
# 51/51 [==============================] - 1s 19ms/step - loss: 0.0623 - acc: 1.0000 - val_loss: 1.5675 - val_acc: 0.5556
#
# Epoch 00085: val_acc did not improve from 0.66667
# Epoch 86/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.0542 - acc: 1.0000 - val_loss: 1.6749 - val_acc: 0.5556
#
# Epoch 00086: val_acc did not improve from 0.66667
# Epoch 87/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0458 - acc: 1.0000 - val_loss: 1.7546 - val_acc: 0.5556
#
# Epoch 00087: val_acc did not improve from 0.66667
# Epoch 88/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.0413 - acc: 1.0000 - val_loss: 1.8097 - val_acc: 0.5556
#
# Epoch 00088: val_acc did not improve from 0.66667
# Epoch 89/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0395 - acc: 1.0000 - val_loss: 1.8686 - val_acc: 0.5000
#
# Epoch 00089: val_acc did not improve from 0.66667
# Epoch 90/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0394 - acc: 1.0000 - val_loss: 1.9096 - val_acc: 0.5000
#
# Epoch 00090: val_acc did not improve from 0.66667
# Epoch 91/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.0389 - acc: 1.0000 - val_loss: 1.9211 - val_acc: 0.3889
#
# Epoch 00091: val_acc did not improve from 0.66667
# Epoch 92/100
# 51/51 [==============================] - 1s 18ms/step - loss: 0.0371 - acc: 1.0000 - val_loss: 1.8884 - val_acc: 0.3889
#
# Epoch 00092: val_acc did not improve from 0.66667
# Epoch 93/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.0342 - acc: 1.0000 - val_loss: 1.8216 - val_acc: 0.3889
#
# Epoch 00093: val_acc did not improve from 0.66667
# Epoch 94/100
# 51/51 [==============================] - 1s 16ms/step - loss: 0.0310 - acc: 1.0000 - val_loss: 1.7526 - val_acc: 0.5000
#
# Epoch 00094: val_acc did not improve from 0.66667
# Epoch 95/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.0284 - acc: 1.0000 - val_loss: 1.6991 - val_acc: 0.5556
#
# Epoch 00095: val_acc did not improve from 0.66667
# Epoch 96/100
# 51/51 [==============================] - 1s 23ms/step - loss: 0.0264 - acc: 1.0000 - val_loss: 1.6690 - val_acc: 0.5556
#
# Epoch 00096: val_acc did not improve from 0.66667
# Epoch 97/100
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0247 - acc: 1.0000 - val_loss: 1.6496 - val_acc: 0.5556
#
# Epoch 00097: val_acc did not improve from 0.66667
# Epoch 98/100
# 51/51 [==============================] - 1s 17ms/step - loss: 0.0234 - acc: 1.0000 - val_loss: 1.6402 - val_acc: 0.6111
#
# Epoch 00098: val_acc did not improve from 0.66667
# Epoch 99/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0224 - acc: 1.0000 - val_loss: 1.6357 - val_acc: 0.6111
#
# Epoch 00099: val_acc did not improve from 0.66667
# Epoch 100/100
# 51/51 [==============================] - 1s 15ms/step - loss: 0.0214 - acc: 1.0000 - val_loss: 1.6378 - val_acc: 0.6111
#
# Epoch 00100: val_acc did not improve from 0.66667
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ['C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//LSTM_model.sav']

# %%
######LogReg################
from sklearn.linear_model import LogisticRegression

logreg = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', LogisticRegression(n_jobs=1, C=1e5)),
               ])
logreg.fit(X_train_1, y_train)
y_pred = logreg.predict(X_test_1)

print('accuracy %s' % accuracy_score(y_pred, y_test))

accuracy_score(y_test, y_pred)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)


print(classification_report(y_test, y_pred))
accuracy['LogReg']=accuracy_score(y_test, y_pred)

cm = confusion_matrix(y_test,y_pred)
pd.DataFrame(cm).to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//LR_confusion.csv')  


'''print(classification_report(y_test, y_pred))




pd.DataFrame(classification_report(y_test, y_pred)).to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//LR_classification.csv')  '''

y_pred = le.inverse_transform(y_pred)
predictions_file = np.column_stack((X_test_1, y_pred))



labelled_data_LR=pd.DataFrame(predictions_file,columns=['Description','Label'])
labelled_data_LR.reset_index().to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//LR_results.csv')  

####Saving the model
# save the model to disk
filename = 'C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//LogReg_model.sav'
joblib.dump(logreg, filename)
# Out:
# accuracy 0.4
#              precision    recall  f1-score   support
#
#           1       0.27      0.38      0.32         8
#           2       0.42      0.62      0.50         8
#           3       0.60      0.75      0.67         4
#           4       0.00      0.00      0.00         5
#           5       0.50      0.20      0.29         5
#
# avg / total       0.35      0.40      0.35        30
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ['C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//LogReg_model.sav']

# %%
#########Naive Bayes###########

nb = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])
nb.fit(X_train_1, y_train)


from sklearn.metrics import classification_report
y_pred = nb.predict(X_test_1)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred))
accuracy['NB']=accuracy_score(y_test, y_pred)



cm = confusion_matrix(y_test,y_pred)
pd.DataFrame(cm).to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//NB_confusion.csv')  

y_pred = le.inverse_transform(y_pred)
predictions_file = np.column_stack((X_test_1, y_pred))

labelled_data_NB=pd.DataFrame(predictions_file,columns=['Description','Label'])
labelled_data_NB.reset_index().to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//NB_results.csv')     

pd.Series(accuracy).to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//Accuracy.csv')  

#####Pickle the file####
filename = 'C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//NB_model.sav'
joblib.dump(nb, filename)
# Out:
# accuracy 0.43333333333333335
#              precision    recall  f1-score   support
#
#           1       0.32      1.00      0.48         8
#           2       1.00      0.38      0.55         8
#           3       1.00      0.50      0.67         4
#           4       0.00      0.00      0.00         5
#           5       0.00      0.00      0.00         5
#
# avg / total       0.49      0.43      0.36        30
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ['C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//NB_model.sav']

# %%
##############XGBOOST##################
import  xgboost, string
from keras.preprocessing import text, sequence
from keras import layers, models, optimizers
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm

# characters level tf-idf
tfidf_vect_ngram_chars = TfidfVectorizer(analyzer='char', token_pattern=r'\w{1,}', ngram_range=(2,3), max_features=5000)
tfidf_vect_ngram_chars.fit(df['Description'])
xtrain_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(X_train_1) 
xvalid_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(X_test_1) 

clf=xgboost.XGBClassifier().fit(xtrain_tfidf_ngram_chars.tocsc(), y_train)

predictions = clf.predict(xvalid_tfidf_ngram_chars)
accuracy['XGB']=metrics.accuracy_score(predictions, y_test)    

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,predictions)



pd.DataFrame(cm).to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//XGB_char_confusion.csv')  

predictions = le.inverse_transform(predictions)
predictions_file = np.column_stack((X_test_1, predictions))

labelled_data_XGB=pd.DataFrame(predictions_file,columns=['Description','Label'])
labelled_data_XGB.reset_index().to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//XGB_results.csv')  
#######Pickel the model##########
filename = 'C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//XGB_model.sav'
Vectorizer='C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//XGB_vectorizer.sav'
joblib.dump(clf, filename)
joblib.dump(tfidf_vect_ngram_chars,Vectorizer)
# Out:
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ['C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//XGB_vectorizer.sav']

# %%
#########SVM ngram chars#############
clf_SVM=SGDClassifier().fit(xtrain_tfidf_ngram_chars.tocsc(), y_train)
predictions = clf_SVM.predict(xvalid_tfidf_ngram_chars)

accuracy['SVM_ngram']=metrics.accuracy_score(predictions, y_test)    

cm_svm_new = confusion_matrix(y_test,predictions)

predictions = le.inverse_transform(predictions)
predictions_file_svm_new = np.column_stack((X_test_1, predictions))

pd.DataFrame(cm_svm_new).to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//SVM_char_confusion.csv')  
labelled_data_SVM_new=pd.DataFrame(predictions_file,columns=['Description','Label'])
labelled_data_SVM_new.reset_index().to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//SVM_char_results.csv')  

#######Pickel the model##########
filename = 'C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//SVM_ngram_model.sav'
joblib.dump(clf_SVM, filename)
# Out:
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ['C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//SVM_ngram_model.sav']

# %%
#####Selction based on accuracy
import scipy.stats
import operator
type(accuracy)
Key=max(accuracy.items(), key=operator.itemgetter(1))[0]
Value=accuracy[max(accuracy.items(), key=operator.itemgetter(1))[0]]

#Load the new data
data_to_predict = pd.read_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//More_Defects_6_11_UI.csv',delimiter=',',encoding='latin-1')
#data_to_predict= data_to_predict.dropna()
#df = df[df.Severity.apply(lambda x: x.isnumeric())]
data_to_predict = data_to_predict[data_to_predict.Category.apply(lambda x: x !="")]
#data_to_predict = data_to_predict[data_to_predict.Category.apply(lambda x: x !="")]
data_to_predict.describe()
data_to_predict.columns
data_to_predict.head()
X_test_predict=data_to_predict['Description']

# load the model

filename_toload='C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//'+Key+'_model.sav'
loaded_model = joblib.load(filename_toload)
if(Key=="XGB"):
    load_vectorizer=joblib.load('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//'+Key+'_vectorizer.sav')
    X_test_predict=load_vectorizer.transform(X_test_predict)
result = loaded_model.predict(X_test_predict)

#predictions_file1 = np.column_stack((X_test_1, result))

result = le.inverse_transform(result)
print(result)
data_to_predict['Predicted Label']=result

#labelled_data_final=pd.DataFrame(predictions_file1,columns=['Description','Label'])
#type(labelled_data_final['Label'][0])
###Map of labels###
map_label={
#0:	'Environment Issue',
#1:	'Data Integrity',
#2:	'Functional Issue',
#3:	'Syntax Issue',
#4:	'Date Issue',
#5:	'Duplicate Issue',
#6:	'Spool Issue',
}

if 'Category' in data_to_predict.columns:
    data_to_predict=data_to_predict.drop(['Category'],axis=1)

#data_to_predict['Predicted Label'] = data_to_predict['Predicted Label'].map(map_label)
data_to_predict.to_csv('C://Users//rupadhyay//Desktop//ML//Defect classification and forecasting//Data//Results2//Final_results.csv')
# Out:
# ['Data Integrity' 'Export Issue' 'Export Issue' 'Export Issue'
#  'Performance Issue' 'Data Integrity' 'Component visibility'
#  'Component visibility' 'Export Issue' 'Export Issue' 'Data Integrity'
#  'Export Issue' 'Export Issue' 'Export Issue' 'Data Integrity'
#  'Component visibility' 'Data Integrity' 'Component visibility'
#  'Component visibility' 'Data Integrity' 'Performance Issue'
#  'Export Issue' 'Export Issue' 'Data Integrity' 'Component visibility'
#  'Inconsistent Component' 'Component visibility' 'Component visibility'
#  'Component visibility' 'Component visibility' 'Data Integrity'
#  'Component visibility' 'Performance Issue' 'Component visibility'
#  'Component visibility' 'Component visibility' 'Component visibility'
#  'Data Integrity' 'Data Integrity' 'Export Issue' 'Performance Issue'
#  'Data Integrity' 'Data Integrity' 'Component visibility'
#  'Component visibility' 'Component visibility' 'Component visibility'
#  'Component visibility' 'Data Integrity' 'Calculation Issue'
#  'Data Integrity' 'Data Integrity' 'Data Integrity' 'Component visibility'
#  'Component visibility' 'Inconsistent Component' 'Export Issue'
#  'Data Integrity' 'Component visibility' 'Component visibility'
#  'Export Issue' 'Data Integrity' 'Data Integrity' 'Data Integrity'
#  'Component visibility' 'Inconsistent Component' 'Inconsistent Component'
#  'Data Integrity' 'Component visibility' 'Component visibility'
#  'Inconsistent Component' 'Inconsistent Component' 'Data Integrity'
#  'Component visibility' 'Component visibility' 'Component visibility'
#  'Component visibility' 'Inconsistent Component' 'Data Integrity'
#  'Component visibility' 'Component visibility' 'Export Issue'
#  'Component visibility' 'Data Integrity' 'Component visibility'
#  'Component visibility' 'Component visibility' 'Performance Issue'
#  'Export Issue' 'Component visibility' 'Component visibility'
#  'Export Issue' 'Data Integrity' 'Component visibility'
#  'Component visibility' 'Data Integrity' 'Data Integrity'
#  'Component visibility' 'Component visibility' 'Data Integrity'
#  'Component visibility' 'Export Issue' 'Data Integrity'
#  'Inconsistent Component' 'Data Integrity' 'Performance Issue'
#  'Component visibility' 'Component visibility' 'Data Integrity'
#  'Data Integrity' 'Component visibility' 'Component visibility'
#  'Component visibility' 'Component visibility' 'Component visibility'
#  'Data Integrity' 'Export Issue' 'Component visibility'
#  'Calculation Issue' 'Component visibility' 'Component visibility'
#  'Export Issue' 'Export Issue' 'Component visibility'
#  'Component visibility' 'Component visibility' 'Component visibility'
#  'Component visibility' 'Data Integrity' 'Component visibility'
#  'Data Integrity' 'Component visibility' 'Inconsistent Component'
#  'Data Integrity' 'Data Integrity' 'Component visibility'
#  'Component visibility' 'Component visibility' 'Component visibility'
#  'Component visibility' 'Export Issue' 'Component visibility'
#  'Export Issue' 'Component visibility' 'Component visibility'
#  'Component visibility' 'Component visibility' 'Export Issue'
#  'Component visibility' 'Component visibility' 'Component visibility'
#  'Component visibility' 'Component visibility' 'Component visibility'
#  'Data Integrity' 'Component visibility' 'Component visibility'
#  'Component visibility' 'Component visibility' 'Component visibility'
#  'Component visibility' 'Performance Issue' 'Component visibility']
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
