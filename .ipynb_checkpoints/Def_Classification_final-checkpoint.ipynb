# %%
"""
Created on Mon Feb  4 14:53:34 2019

@author: pousarkar
"""
from sklearn.metrics import classification_report

import keras 
import numpy as np
from keras.preprocessing.text import Tokenizer
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Input, Dense, Dropout, Embedding, LSTM, Flatten
from keras.models import Model
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
plt.style.use('ggplot')
#%matplotlib inline
from IPython.core.display import display, HTML
import logging
import pandas as pd
import numpy as np
from numpy import random
import gensim
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re
from bs4 import BeautifulSoup

from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer



from sklearn.linear_model import SGDClassifier

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

accuracy={}
df = pd.read_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//class1.csv',delimiter=',',encoding='latin-1')
df= df.dropna()
#df = df[df.Severity.apply(lambda x: x.isnumeric())]
df = df[df.Category.apply(lambda x: x !="")]
df = df[df.Category.apply(lambda x: x !="")]
df.describe()

df.head()

df.Category.value_counts()
# Out:
# 2    285
# 1    107
# 3     59
# 5     31
# 4     20
# 6     13
# 0     11
# Name: Category, dtype: int64

# %%
def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
    return text
    
df['Description'] = df['Description'].apply(clean_text)


df['target'] = df.Category.astype('category').cat.codes

df['num_words'] = df.Description.apply(lambda x : len(x.split()))


bins=[0,50,75, np.inf]
df['bins']=pd.cut(df.num_words, bins=[0,100,300,500,800, np.inf], labels=['0-100', '100-300', '300-500','500-800' ,'>800'])

word_distribution = df.groupby('bins').size().reset_index().rename(columns={0:'counts'})

word_distribution.head()

sns.barplot(x='bins', y='counts', data=word_distribution).set_title("Word distribution per bin")
df.head(10)

num_class = len(np.unique(df.Category.values))
y = df['target'].values

X_train_1, X_test_1, y_train, y_test = train_test_split(df.Description.values, y, test_size=0.3)

# %%
#####RNN###############
MAX_LENGTH = 500
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train_1)
post_seq = tokenizer.texts_to_sequences(X_train_1)
post_seq_padded = pad_sequences(post_seq, maxlen=MAX_LENGTH)

X_train=post_seq_padded

tokenizer.fit_on_texts(X_test_1)
post_seq_test = tokenizer.texts_to_sequences(X_test_1)
post_seq_padded_test = pad_sequences(post_seq_test, maxlen=MAX_LENGTH)

X_test=post_seq_padded_test

#X_train, X_test, y_train, y_test = train_test_split(post_seq_padded, y, test_size=0.3)

vocab_size = len(tokenizer.word_index) + 1


inputs = Input(shape=(MAX_LENGTH, ))
embedding_layer = Embedding(vocab_size,
                            128,
                            input_length=MAX_LENGTH)(inputs)
x = Flatten()(embedding_layer)
x = Dense(32, activation='relu')(x)

predictions = Dense(num_class, activation='softmax')(x)
model = Model(inputs=[inputs], outputs=predictions)
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])


model.summary()
filepath="weights-simple.hdf5"
checkpointer = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
history = model.fit([X_train], batch_size=10, y=to_categorical(y_train), verbose=1, validation_split=0.25, 
          shuffle=True, epochs=100, callbacks=[checkpointer])

df1 = pd.DataFrame({'epochs':history.epoch, 'accuracy': history.history['acc'], 'validation_accuracy': history.history['val_acc']})
g = sns.pointplot(x="epochs", y="accuracy", data=df1, fit_reg=False)
g = sns.pointplot(x="epochs", y="validation_accuracy", data=df1, fit_reg=False, color='green')


predicted = model.predict(X_test)
predicted = np.argmax(predicted, axis=1)
accuracy_score(y_test, predicted)
accuracy['RNN']=accuracy_score(y_test, predicted)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,predicted)
pd.DataFrame(cm).to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//RNN_confusion.csv')  

'''print((classification_report(y_test, predicted)))
type(report)
pd.DataFrame(report).to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//RNN_classification.csv')'''

####Reverse dictionary

predictions_human_readable = np.column_stack((X_test_1, predicted))


labelled_data=pd.DataFrame(predictions_human_readable,columns=['Description','Label'])
labelled_data.reset_index().to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//RNN_results.csv')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 500)               0
# _________________________________________________________________
# embedding_1 (Embedding)      (None, 500, 128)          339072
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64000)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2048032
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 2,387,335
# Trainable params: 2,387,335
# Non-trainable params: 0
# _________________________________________________________________
# Train on 276 samples, validate on 92 samples
# Epoch 1/100
# 276/276 [==============================] - 3s 10ms/step - loss: 1.5639 - acc: 0.4457 - val_loss: 1.5168 - val_acc: 0.1957
#
# Epoch 00001: val_acc improved from -inf to 0.19565, saving model to weights-simple.hdf5
# Epoch 2/100
# 276/276 [==============================] - 2s 8ms/step - loss: 1.3630 - acc: 0.4710 - val_loss: 1.3243 - val_acc: 0.5870
#
# Epoch 00002: val_acc improved from 0.19565 to 0.58696, saving model to weights-simple.hdf5
# Epoch 3/100
# 276/276 [==============================] - 2s 8ms/step - loss: 1.1201 - acc: 0.6196 - val_loss: 1.3173 - val_acc: 0.5870
#
# Epoch 00003: val_acc did not improve from 0.58696
# Epoch 4/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.8649 - acc: 0.7283 - val_loss: 1.2932 - val_acc: 0.5870
#
# Epoch 00004: val_acc did not improve from 0.58696
# Epoch 5/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.6075 - acc: 0.8442 - val_loss: 1.2722 - val_acc: 0.6087
#
# Epoch 00005: val_acc improved from 0.58696 to 0.60870, saving model to weights-simple.hdf5
# Epoch 6/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.4489 - acc: 0.8732 - val_loss: 1.2897 - val_acc: 0.5978
#
# Epoch 00006: val_acc did not improve from 0.60870
# Epoch 7/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.3537 - acc: 0.8913 - val_loss: 1.2516 - val_acc: 0.6196
#
# Epoch 00007: val_acc improved from 0.60870 to 0.61957, saving model to weights-simple.hdf5
# Epoch 8/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.2859 - acc: 0.9058 - val_loss: 1.2542 - val_acc: 0.6304
#
# Epoch 00008: val_acc improved from 0.61957 to 0.63043, saving model to weights-simple.hdf5
# Epoch 9/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.2359 - acc: 0.9203 - val_loss: 1.2649 - val_acc: 0.6304
#
# Epoch 00009: val_acc did not improve from 0.63043
# Epoch 10/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.1987 - acc: 0.9239 - val_loss: 1.2845 - val_acc: 0.6413
#
# Epoch 00010: val_acc improved from 0.63043 to 0.64130, saving model to weights-simple.hdf5
# Epoch 11/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.1473 - acc: 0.9529 - val_loss: 1.2798 - val_acc: 0.6413
#
# Epoch 00011: val_acc did not improve from 0.64130
# Epoch 12/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0963 - acc: 0.9855 - val_loss: 1.2932 - val_acc: 0.6304
#
# Epoch 00012: val_acc did not improve from 0.64130
# Epoch 13/100
# 276/276 [==============================] - 2s 9ms/step - loss: 0.0682 - acc: 0.9964 - val_loss: 1.3377 - val_acc: 0.6413
#
# Epoch 00013: val_acc did not improve from 0.64130
# Epoch 14/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0548 - acc: 0.9928 - val_loss: 1.3324 - val_acc: 0.6630
#
# Epoch 00014: val_acc improved from 0.64130 to 0.66304, saving model to weights-simple.hdf5
# Epoch 15/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0392 - acc: 1.0000 - val_loss: 1.3451 - val_acc: 0.6304
#
# Epoch 00015: val_acc did not improve from 0.66304
# Epoch 16/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0294 - acc: 1.0000 - val_loss: 1.3724 - val_acc: 0.6304
#
# Epoch 00016: val_acc did not improve from 0.66304
# Epoch 17/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0230 - acc: 1.0000 - val_loss: 1.3615 - val_acc: 0.6304
#
# Epoch 00017: val_acc did not improve from 0.66304
# Epoch 18/100
# 276/276 [==============================] - 3s 9ms/step - loss: 0.0182 - acc: 1.0000 - val_loss: 1.4174 - val_acc: 0.6304
#
# Epoch 00018: val_acc did not improve from 0.66304
# Epoch 19/100
# 276/276 [==============================] - 3s 10ms/step - loss: 0.0153 - acc: 1.0000 - val_loss: 1.3957 - val_acc: 0.6304
#
# Epoch 00019: val_acc did not improve from 0.66304
# Epoch 20/100
# 276/276 [==============================] - 2s 9ms/step - loss: 0.0127 - acc: 1.0000 - val_loss: 1.4172 - val_acc: 0.6304
#
# Epoch 00020: val_acc did not improve from 0.66304
# Epoch 21/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0112 - acc: 1.0000 - val_loss: 1.4204 - val_acc: 0.6196
#
# Epoch 00021: val_acc did not improve from 0.66304
# Epoch 22/100
# 276/276 [==============================] - 3s 9ms/step - loss: 0.0087 - acc: 1.0000 - val_loss: 1.4440 - val_acc: 0.6304
#
# Epoch 00022: val_acc did not improve from 0.66304
# Epoch 23/100
# 276/276 [==============================] - 3s 10ms/step - loss: 0.0075 - acc: 1.0000 - val_loss: 1.4391 - val_acc: 0.6196
#
# Epoch 00023: val_acc did not improve from 0.66304
# Epoch 24/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0064 - acc: 1.0000 - val_loss: 1.4574 - val_acc: 0.6196
#
# Epoch 00024: val_acc did not improve from 0.66304
# Epoch 25/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0056 - acc: 1.0000 - val_loss: 1.4637 - val_acc: 0.6196
#
# Epoch 00025: val_acc did not improve from 0.66304
# Epoch 26/100
# 276/276 [==============================] - 3s 10ms/step - loss: 0.0049 - acc: 1.0000 - val_loss: 1.4790 - val_acc: 0.6196
#
# Epoch 00026: val_acc did not improve from 0.66304
# Epoch 27/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0044 - acc: 1.0000 - val_loss: 1.4953 - val_acc: 0.6196
#
# Epoch 00027: val_acc did not improve from 0.66304
# Epoch 28/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0039 - acc: 1.0000 - val_loss: 1.4850 - val_acc: 0.6196
#
# Epoch 00028: val_acc did not improve from 0.66304
# Epoch 29/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0035 - acc: 1.0000 - val_loss: 1.5085 - val_acc: 0.6196
#
# Epoch 00029: val_acc did not improve from 0.66304
# Epoch 30/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0032 - acc: 1.0000 - val_loss: 1.5162 - val_acc: 0.6196
#
# Epoch 00030: val_acc did not improve from 0.66304
# Epoch 31/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 1.5125 - val_acc: 0.6196
#
# Epoch 00031: val_acc did not improve from 0.66304
# Epoch 32/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0027 - acc: 1.0000 - val_loss: 1.5304 - val_acc: 0.6196
#
# Epoch 00032: val_acc did not improve from 0.66304
# Epoch 33/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0025 - acc: 1.0000 - val_loss: 1.5407 - val_acc: 0.6196
#
# Epoch 00033: val_acc did not improve from 0.66304
# Epoch 34/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 1.5442 - val_acc: 0.6196
#
# Epoch 00034: val_acc did not improve from 0.66304
# Epoch 35/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 1.5480 - val_acc: 0.6196
#
# Epoch 00035: val_acc did not improve from 0.66304
# Epoch 36/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 1.5522 - val_acc: 0.6196
#
# Epoch 00036: val_acc did not improve from 0.66304
# Epoch 37/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 1.5583 - val_acc: 0.6196
#
# Epoch 00037: val_acc did not improve from 0.66304
# Epoch 38/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 1.5670 - val_acc: 0.6196
#
# Epoch 00038: val_acc did not improve from 0.66304
# Epoch 39/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 1.5765 - val_acc: 0.6196
#
# Epoch 00039: val_acc did not improve from 0.66304
# Epoch 40/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 1.5779 - val_acc: 0.6196
#
# Epoch 00040: val_acc did not improve from 0.66304
# Epoch 41/100
# 276/276 [==============================] - 2s 8ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 1.5865 - val_acc: 0.6196
#
# Epoch 00041: val_acc did not improve from 0.66304
# Epoch 42/100
# 276/276 [==============================] - 3s 9ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 1.5884 - val_acc: 0.6196
#
# Epoch 00042: val_acc did not improve from 0.66304
# Epoch 43/100
# 276/276 [==============================] - 3s 10ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.5955 - val_acc: 0.6196
#
# Epoch 00043: val_acc did not improve from 0.66304
# Epoch 44/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.5980 - val_acc: 0.6196
#
# Epoch 00044: val_acc did not improve from 0.66304
# Epoch 45/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 1.6125 - val_acc: 0.6196
#
# Epoch 00045: val_acc did not improve from 0.66304
# Epoch 46/100
# 276/276 [==============================] - 3s 10ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 1.6080 - val_acc: 0.6196
#
# Epoch 00046: val_acc did not improve from 0.66304
# Epoch 47/100
# 276/276 [==============================] - 3s 10ms/step - loss: 9.8595e-04 - acc: 1.0000 - val_loss: 1.6148 - val_acc: 0.6196
#
# Epoch 00047: val_acc did not improve from 0.66304
# Epoch 48/100
# 276/276 [==============================] - 2s 8ms/step - loss: 9.3928e-04 - acc: 1.0000 - val_loss: 1.6264 - val_acc: 0.6196
#
# Epoch 00048: val_acc did not improve from 0.66304
# Epoch 49/100
# 276/276 [==============================] - 2s 8ms/step - loss: 8.9342e-04 - acc: 1.0000 - val_loss: 1.6321 - val_acc: 0.6196
#
# Epoch 00049: val_acc did not improve from 0.66304
# Epoch 50/100
# 276/276 [==============================] - 2s 8ms/step - loss: 8.4921e-04 - acc: 1.0000 - val_loss: 1.6332 - val_acc: 0.6196
#
# Epoch 00050: val_acc did not improve from 0.66304
# Epoch 51/100
# 276/276 [==============================] - 2s 8ms/step - loss: 8.1230e-04 - acc: 1.0000 - val_loss: 1.6331 - val_acc: 0.6196
#
# Epoch 00051: val_acc did not improve from 0.66304
# Epoch 52/100
# 276/276 [==============================] - 2s 8ms/step - loss: 7.7612e-04 - acc: 1.0000 - val_loss: 1.6409 - val_acc: 0.6196
#
# Epoch 00052: val_acc did not improve from 0.66304
# Epoch 53/100
# 276/276 [==============================] - 2s 8ms/step - loss: 7.4265e-04 - acc: 1.0000 - val_loss: 1.6556 - val_acc: 0.6196
#
# Epoch 00053: val_acc did not improve from 0.66304
# Epoch 54/100
# 276/276 [==============================] - 2s 8ms/step - loss: 7.0715e-04 - acc: 1.0000 - val_loss: 1.6502 - val_acc: 0.6196
#
# Epoch 00054: val_acc did not improve from 0.66304
# Epoch 55/100
# 276/276 [==============================] - 2s 8ms/step - loss: 6.7346e-04 - acc: 1.0000 - val_loss: 1.6517 - val_acc: 0.6196
#
# Epoch 00055: val_acc did not improve from 0.66304
# Epoch 56/100
# 276/276 [==============================] - 2s 8ms/step - loss: 6.4641e-04 - acc: 1.0000 - val_loss: 1.6678 - val_acc: 0.6196
#
# Epoch 00056: val_acc did not improve from 0.66304
# Epoch 57/100
# 276/276 [==============================] - 2s 8ms/step - loss: 6.1718e-04 - acc: 1.0000 - val_loss: 1.6638 - val_acc: 0.6196
#
# Epoch 00057: val_acc did not improve from 0.66304
# Epoch 58/100
# 276/276 [==============================] - 2s 8ms/step - loss: 5.9219e-04 - acc: 1.0000 - val_loss: 1.6676 - val_acc: 0.6196
#
# Epoch 00058: val_acc did not improve from 0.66304
# Epoch 59/100
# 276/276 [==============================] - 2s 8ms/step - loss: 5.7218e-04 - acc: 1.0000 - val_loss: 1.6784 - val_acc: 0.6196
#
# Epoch 00059: val_acc did not improve from 0.66304
# Epoch 60/100
# 276/276 [==============================] - 2s 8ms/step - loss: 5.4844e-04 - acc: 1.0000 - val_loss: 1.6807 - val_acc: 0.6196
#
# Epoch 00060: val_acc did not improve from 0.66304
# Epoch 61/100
# 276/276 [==============================] - 2s 8ms/step - loss: 5.2920e-04 - acc: 1.0000 - val_loss: 1.6809 - val_acc: 0.6196
#
# Epoch 00061: val_acc did not improve from 0.66304
# Epoch 62/100
# 276/276 [==============================] - 2s 8ms/step - loss: 5.0695e-04 - acc: 1.0000 - val_loss: 1.6860 - val_acc: 0.6196
#
# Epoch 00062: val_acc did not improve from 0.66304
# Epoch 63/100
# 276/276 [==============================] - 3s 10ms/step - loss: 4.8685e-04 - acc: 1.0000 - val_loss: 1.6873 - val_acc: 0.6196
#
# Epoch 00063: val_acc did not improve from 0.66304
# Epoch 64/100
# 276/276 [==============================] - 3s 12ms/step - loss: 4.6864e-04 - acc: 1.0000 - val_loss: 1.6954 - val_acc: 0.6196
#
# Epoch 00064: val_acc did not improve from 0.66304
# Epoch 65/100
# 276/276 [==============================] - 3s 11ms/step - loss: 4.5191e-04 - acc: 1.0000 - val_loss: 1.6953 - val_acc: 0.6196
#
# Epoch 00065: val_acc did not improve from 0.66304
# Epoch 66/100
# 276/276 [==============================] - 4s 13ms/step - loss: 4.3607e-04 - acc: 1.0000 - val_loss: 1.7056 - val_acc: 0.6196
#
# Epoch 00066: val_acc did not improve from 0.66304
# Epoch 67/100
# 276/276 [==============================] - 4s 13ms/step - loss: 4.1901e-04 - acc: 1.0000 - val_loss: 1.7050 - val_acc: 0.6196
#
# Epoch 00067: val_acc did not improve from 0.66304
# Epoch 68/100
# 276/276 [==============================] - 3s 11ms/step - loss: 4.0524e-04 - acc: 1.0000 - val_loss: 1.7101 - val_acc: 0.6196
#
# Epoch 00068: val_acc did not improve from 0.66304
# Epoch 69/100
# 276/276 [==============================] - 3s 9ms/step - loss: 3.9082e-04 - acc: 1.0000 - val_loss: 1.7100 - val_acc: 0.6196
#
# Epoch 00069: val_acc did not improve from 0.66304
# Epoch 70/100
# 276/276 [==============================] - 2s 8ms/step - loss: 3.7734e-04 - acc: 1.0000 - val_loss: 1.7154 - val_acc: 0.6196
#
# Epoch 00070: val_acc did not improve from 0.66304
# Epoch 71/100
# 276/276 [==============================] - 2s 8ms/step - loss: 3.6448e-04 - acc: 1.0000 - val_loss: 1.7252 - val_acc: 0.6196
#
# Epoch 00071: val_acc did not improve from 0.66304
# Epoch 72/100
# 276/276 [==============================] - 2s 8ms/step - loss: 3.5296e-04 - acc: 1.0000 - val_loss: 1.7271 - val_acc: 0.6196
#
# Epoch 00072: val_acc did not improve from 0.66304
# Epoch 73/100
# 276/276 [==============================] - 2s 8ms/step - loss: 3.4128e-04 - acc: 1.0000 - val_loss: 1.7231 - val_acc: 0.6196
#
# Epoch 00073: val_acc did not improve from 0.66304
# Epoch 74/100
# 276/276 [==============================] - 3s 9ms/step - loss: 3.2997e-04 - acc: 1.0000 - val_loss: 1.7344 - val_acc: 0.6196
#
# Epoch 00074: val_acc did not improve from 0.66304
# Epoch 75/100
# 276/276 [==============================] - 3s 9ms/step - loss: 3.1910e-04 - acc: 1.0000 - val_loss: 1.7328 - val_acc: 0.6196
#
# Epoch 00075: val_acc did not improve from 0.66304
# Epoch 76/100
# 276/276 [==============================] - 2s 7ms/step - loss: 3.0939e-04 - acc: 1.0000 - val_loss: 1.7415 - val_acc: 0.6196
#
# Epoch 00076: val_acc did not improve from 0.66304
# Epoch 77/100
# 276/276 [==============================] - 2s 8ms/step - loss: 2.9910e-04 - acc: 1.0000 - val_loss: 1.7461 - val_acc: 0.6196
#
# Epoch 00077: val_acc did not improve from 0.66304
# Epoch 78/100
# 276/276 [==============================] - 2s 8ms/step - loss: 2.9079e-04 - acc: 1.0000 - val_loss: 1.7431 - val_acc: 0.6196
#
# Epoch 00078: val_acc did not improve from 0.66304
# Epoch 79/100
# 276/276 [==============================] - 2s 7ms/step - loss: 2.8073e-04 - acc: 1.0000 - val_loss: 1.7475 - val_acc: 0.6196
#
# Epoch 00079: val_acc did not improve from 0.66304
# Epoch 80/100
# 276/276 [==============================] - 2s 8ms/step - loss: 2.7332e-04 - acc: 1.0000 - val_loss: 1.7505 - val_acc: 0.6196
#
# Epoch 00080: val_acc did not improve from 0.66304
# Epoch 81/100
# 276/276 [==============================] - 2s 9ms/step - loss: 2.6564e-04 - acc: 1.0000 - val_loss: 1.7600 - val_acc: 0.6196
# Epoch 00081: val_acc did not improve from 0.66304
# Epoch 82/100
# 276/276 [==============================] - 3s 10ms/step - loss: 2.5721e-04 - acc: 1.0000 - val_loss: 1.7538 - val_acc: 0.6196
#
# Epoch 00082: val_acc did not improve from 0.66304
# Epoch 83/100
# 276/276 [==============================] - 3s 12ms/step - loss: 2.4882e-04 - acc: 1.0000 - val_loss: 1.7649 - val_acc: 0.6196
#
# Epoch 00083: val_acc did not improve from 0.66304
# Epoch 84/100
# 276/276 [==============================] - 3s 13ms/step - loss: 2.4184e-04 - acc: 1.0000 - val_loss: 1.7679 - val_acc: 0.6196
#
# Epoch 00084: val_acc did not improve from 0.66304
# Epoch 85/100
# 276/276 [==============================] - 3s 11ms/step - loss: 2.3526e-04 - acc: 1.0000 - val_loss: 1.7691 - val_acc: 0.6196
#
# Epoch 00085: val_acc did not improve from 0.66304
# Epoch 86/100
# 276/276 [==============================] - 3s 11ms/step - loss: 2.2840e-04 - acc: 1.0000 - val_loss: 1.7690 - val_acc: 0.6196
#
# Epoch 00086: val_acc did not improve from 0.66304
# Epoch 87/100
# 276/276 [==============================] - 3s 11ms/step - loss: 2.2195e-04 - acc: 1.0000 - val_loss: 1.7719 - val_acc: 0.6087
#
# Epoch 00087: val_acc did not improve from 0.66304
# Epoch 88/100
# 276/276 [==============================] - 3s 9ms/step - loss: 2.1576e-04 - acc: 1.0000 - val_loss: 1.7830 - val_acc: 0.6087
#
# Epoch 00088: val_acc did not improve from 0.66304
# Epoch 89/100
# 276/276 [==============================] - 2s 8ms/step - loss: 2.0943e-04 - acc: 1.0000 - val_loss: 1.7818 - val_acc: 0.6196
#
# Epoch 00089: val_acc did not improve from 0.66304
# Epoch 90/100
# 276/276 [==============================] - 2s 8ms/step - loss: 2.0412e-04 - acc: 1.0000 - val_loss: 1.7859 - val_acc: 0.6087
#
# Epoch 00090: val_acc did not improve from 0.66304
# Epoch 91/100
# 276/276 [==============================] - 2s 8ms/step - loss: 1.9805e-04 - acc: 1.0000 - val_loss: 1.7850 - val_acc: 0.6087
#
# Epoch 00091: val_acc did not improve from 0.66304
# Epoch 92/100
# 276/276 [==============================] - 3s 9ms/step - loss: 1.9275e-04 - acc: 1.0000 - val_loss: 1.7916 - val_acc: 0.6196
#
# Epoch 00092: val_acc did not improve from 0.66304
# Epoch 93/100
# 276/276 [==============================] - 2s 9ms/step - loss: 1.8736e-04 - acc: 1.0000 - val_loss: 1.7901 - val_acc: 0.6087
#
# Epoch 00093: val_acc did not improve from 0.66304
# Epoch 94/100
# 276/276 [==============================] - 2s 8ms/step - loss: 1.8268e-04 - acc: 1.0000 - val_loss: 1.7991 - val_acc: 0.6087
#
# Epoch 00094: val_acc did not improve from 0.66304
# Epoch 95/100
# 276/276 [==============================] - 2s 8ms/step - loss: 1.7784e-04 - acc: 1.0000 - val_loss: 1.7962 - val_acc: 0.6087
#
# Epoch 00095: val_acc did not improve from 0.66304
# Epoch 96/100
# 276/276 [==============================] - 3s 9ms/step - loss: 1.7296e-04 - acc: 1.0000 - val_loss: 1.8043 - val_acc: 0.6087
#
# Epoch 00096: val_acc did not improve from 0.66304
# Epoch 97/100
# 276/276 [==============================] - 2s 8ms/step - loss: 1.6887e-04 - acc: 1.0000 - val_loss: 1.8096 - val_acc: 0.6087
#
# Epoch 00097: val_acc did not improve from 0.66304
# Epoch 98/100
# 276/276 [==============================] - 2s 8ms/step - loss: 1.6462e-04 - acc: 1.0000 - val_loss: 1.8072 - val_acc: 0.6087
#
# Epoch 00098: val_acc did not improve from 0.66304
# Epoch 99/100
# 276/276 [==============================] - 2s 8ms/step - loss: 1.5977e-04 - acc: 1.0000 - val_loss: 1.8141 - val_acc: 0.6087
#
# Epoch 00099: val_acc did not improve from 0.66304
# Epoch 100/100
# 276/276 [==============================] - 2s 8ms/step - loss: 1.5597e-04 - acc: 1.0000 - val_loss: 1.8137 - val_acc: 0.6087
#
# Epoch 00100: val_acc did not improve from 0.66304

# %%
##############################SVM##########################

sgd = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=15, tol=None)),
               ])
sgd.fit(X_train_1, y_train)


y_pred = sgd.predict(X_test_1)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred))

accuracy['SVM']=accuracy_score(y_test, y_pred)


predictions_file = np.column_stack((X_test_1, y_pred))
print(classification_report(y_test, y_pred))

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,predicted)
pd.DataFrame(cm).to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//SVM_confusion.csv')  

'''pd.DataFrame(classification_report(y_test, predicted)).to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//SVM_classification.csv')'''  


labelled_data_SVM=pd.DataFrame(predictions_file,columns=['Description','Label'])
labelled_data_SVM.reset_index().to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//SVM_results.csv')
# Out:
# accuracy 0.6518987341772152
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         3
#           1       0.46      0.41      0.44        29
#           2       0.68      0.82      0.74        87
#           3       0.77      0.59      0.67        17
#           4       0.67      0.33      0.44         6
#           5       0.43      0.27      0.33        11
#           6       1.00      1.00      1.00         5
#
# avg / total       0.63      0.65      0.63       158
#
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         3
#           1       0.46      0.41      0.44        29
#           2       0.68      0.82      0.74        87
#           3       0.77      0.59      0.67        17
#           4       0.67      0.33      0.44         6
#           5       0.43      0.27      0.33        11
#           6       1.00      1.00      1.00         5
#
# avg / total       0.63      0.65      0.63       158
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
##################LSTM####################

inputs = Input(shape=(MAX_LENGTH, ))
embedding_layer = Embedding(vocab_size,
                            128,
                            input_length=MAX_LENGTH)(inputs)

x = LSTM(64)(embedding_layer)
x = Dense(32, activation='relu')(x)
predictions = Dense(num_class, activation='softmax')(x)
model = Model(inputs=[inputs], outputs=predictions)
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])

model.summary()


filepath="weights.hdf5"
checkpointer = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
history = model.fit([X_train], batch_size=50, y=to_categorical(y_train), verbose=1, validation_split=0.25, 
          shuffle=True, epochs=100, callbacks=[checkpointer])


df2 = pd.DataFrame({'epochs':history.epoch, 'accuracy': history.history['acc'], 'validation_accuracy': history.history['val_acc']})
g = sns.pointplot(x="epochs", y="accuracy", data=df2, fit_reg=False)
g = sns.pointplot(x="epochs", y="validation_accuracy", data=df2, fit_reg=False, color='green')



model.load_weights('weights.hdf5')
predicted = model.predict(X_test)

predicted = np.argmax(predicted, axis=1)

accuracy_score(y_test, predicted)
accuracy['LSTM']=accuracy_score(y_test, predicted)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,predicted)
pd.DataFrame(cm).to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//LSTM_confusion.csv')  


'''print(classification_report(y_test, predicted))

pd.DataFrame(classification_report(y_test, predicted)).to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//LSTM_classification.csv')  '''

####Reverse dictionary

predictions_human_readable = np.column_stack((X_test_1, predicted))


labelled_data=pd.DataFrame(predictions_human_readable,columns=['Description','Label'])
labelled_data.reset_index().to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//LSTM_results.csv')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 500)               0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 500, 128)          339072
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 390,791
# Trainable params: 390,791
# Non-trainable params: 0
# _________________________________________________________________
# Train on 276 samples, validate on 92 samples
# Epoch 1/100
# 276/276 [==============================] - 4s 14ms/step - loss: 1.9300 - acc: 0.4239 - val_loss: 1.8971 - val_acc: 0.5870
#
# Epoch 00001: val_acc improved from -inf to 0.58696, saving model to weights.hdf5
# Epoch 2/100
# 276/276 [==============================] - 4s 13ms/step - loss: 1.8566 - acc: 0.5217 - val_loss: 1.7612 - val_acc: 0.5870
#
# Epoch 00002: val_acc did not improve from 0.58696
# Epoch 3/100
# 276/276 [==============================] - 4s 13ms/step - loss: 1.6111 - acc: 0.5217 - val_loss: 1.3894 - val_acc: 0.5870
#
# Epoch 00003: val_acc did not improve from 0.58696
# Epoch 4/100
# 276/276 [==============================] - 4s 13ms/step - loss: 1.4373 - acc: 0.5217 - val_loss: 1.3512 - val_acc: 0.5870
#
# Epoch 00004: val_acc did not improve from 0.58696
# Epoch 5/100
# 276/276 [==============================] - 3s 11ms/step - loss: 1.3281 - acc: 0.5217 - val_loss: 1.3218 - val_acc: 0.5870
#
# Epoch 00005: val_acc did not improve from 0.58696
# Epoch 6/100
# 276/276 [==============================] - 4s 15ms/step - loss: 1.2486 - acc: 0.5217 - val_loss: 1.2811 - val_acc: 0.5870
#
# Epoch 00006: val_acc did not improve from 0.58696
# Epoch 7/100
# 276/276 [==============================] - 4s 13ms/step - loss: 1.1491 - acc: 0.5217 - val_loss: 1.2368 - val_acc: 0.5870
#
# Epoch 00007: val_acc did not improve from 0.58696
# Epoch 8/100
# 276/276 [==============================] - 3s 12ms/step - loss: 1.0250 - acc: 0.5326 - val_loss: 1.1920 - val_acc: 0.5870
#
# Epoch 00008: val_acc did not improve from 0.58696
# Epoch 9/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.9050 - acc: 0.5870 - val_loss: 1.1636 - val_acc: 0.6087
#
# Epoch 00009: val_acc improved from 0.58696 to 0.60870, saving model to weights.hdf5
# Epoch 10/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.7943 - acc: 0.7029 - val_loss: 1.3107 - val_acc: 0.5978
#
# Epoch 00010: val_acc did not improve from 0.60870
# Epoch 11/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.6915 - acc: 0.7826 - val_loss: 1.1750 - val_acc: 0.5652
#
# Epoch 00011: val_acc did not improve from 0.60870
# Epoch 12/100
# 276/276 [==============================] - 4s 14ms/step - loss: 0.5554 - acc: 0.8442 - val_loss: 1.3536 - val_acc: 0.6196
#
# Epoch 00012: val_acc improved from 0.60870 to 0.61957, saving model to weights.hdf5
# Epoch 13/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.4430 - acc: 0.8696 - val_loss: 1.3216 - val_acc: 0.6196
#
# Epoch 00013: val_acc did not improve from 0.61957
# Epoch 14/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.3802 - acc: 0.8659 - val_loss: 1.5618 - val_acc: 0.4891
#
# Epoch 00014: val_acc did not improve from 0.61957
# Epoch 15/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.4243 - acc: 0.8442 - val_loss: 1.4032 - val_acc: 0.6087
#
# Epoch 00015: val_acc did not improve from 0.61957
# Epoch 16/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.3531 - acc: 0.8804 - val_loss: 1.3517 - val_acc: 0.5761
#
# Epoch 00016: val_acc did not improve from 0.61957
# Epoch 17/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.3007 - acc: 0.9058 - val_loss: 1.3686 - val_acc: 0.5435
#
# Epoch 00017: val_acc did not improve from 0.61957
# Epoch 18/100
# 276/276 [==============================] - 5s 20ms/step - loss: 0.2721 - acc: 0.9058 - val_loss: 1.5525 - val_acc: 0.5435
#
# Epoch 00018: val_acc did not improve from 0.61957
# Epoch 19/100
# 276/276 [==============================] - 9s 32ms/step - loss: 0.2507 - acc: 0.9130 - val_loss: 1.6641 - val_acc: 0.5870
#
# Epoch 00019: val_acc did not improve from 0.61957
# Epoch 20/100
# 276/276 [==============================] - 6s 21ms/step - loss: 0.2328 - acc: 0.9130 - val_loss: 1.6356 - val_acc: 0.5978
#
# Epoch 00020: val_acc did not improve from 0.61957
# Epoch 21/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.2188 - acc: 0.9203 - val_loss: 1.7120 - val_acc: 0.6087
#
# Epoch 00021: val_acc did not improve from 0.61957
# Epoch 22/100
# 276/276 [==============================] - 5s 17ms/step - loss: 0.2067 - acc: 0.9239 - val_loss: 1.8106 - val_acc: 0.6413
#
# Epoch 00022: val_acc improved from 0.61957 to 0.64130, saving model to weights.hdf5
# Epoch 23/100
# 276/276 [==============================] - 5s 19ms/step - loss: 0.1963 - acc: 0.9312 - val_loss: 1.8631 - val_acc: 0.5652
#
# Epoch 00023: val_acc did not improve from 0.64130
# Epoch 24/100
# 276/276 [==============================] - 4s 14ms/step - loss: 0.1858 - acc: 0.9275 - val_loss: 1.8455 - val_acc: 0.5652
#
# Epoch 00024: val_acc did not improve from 0.64130
# Epoch 25/100
# 276/276 [==============================] - 4s 16ms/step - loss: 0.1743 - acc: 0.9348 - val_loss: 1.9222 - val_acc: 0.5978
#
# Epoch 00025: val_acc did not improve from 0.64130
# Epoch 26/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.1621 - acc: 0.9384 - val_loss: 1.9640 - val_acc: 0.6087
#
# Epoch 00026: val_acc did not improve from 0.64130
# Epoch 27/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.1486 - acc: 0.9565 - val_loss: 1.9625 - val_acc: 0.6196
#
# Epoch 00027: val_acc did not improve from 0.64130
# Epoch 28/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.1352 - acc: 0.9710 - val_loss: 2.0105 - val_acc: 0.6413
#
# Epoch 00028: val_acc did not improve from 0.64130
# Epoch 29/100
# 276/276 [==============================] - 3s 13ms/step - loss: 0.1206 - acc: 0.9783 - val_loss: 2.0233 - val_acc: 0.6196
#
# Epoch 00029: val_acc did not improve from 0.64130
# Epoch 30/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.1964 - acc: 0.9601 - val_loss: 1.8379 - val_acc: 0.5543
#
# Epoch 00030: val_acc did not improve from 0.64130
# Epoch 31/100
# 276/276 [==============================] - 4s 16ms/step - loss: 0.1670 - acc: 0.9493 - val_loss: 1.8645 - val_acc: 0.5652
#
# Epoch 00031: val_acc did not improve from 0.64130
# Epoch 32/100
# 276/276 [==============================] - 5s 19ms/step - loss: 0.1630 - acc: 0.9674 - val_loss: 1.9066 - val_acc: 0.6087
#
# Epoch 00032: val_acc did not improve from 0.64130
# Epoch 33/100
# 276/276 [==============================] - 5s 18ms/step - loss: 0.1240 - acc: 0.9674 - val_loss: 1.8209 - val_acc: 0.6196
#
# Epoch 00033: val_acc did not improve from 0.64130
# Epoch 34/100
# 276/276 [==============================] - 7s 25ms/step - loss: 0.0953 - acc: 0.9891 - val_loss: 1.7858 - val_acc: 0.6304
#
# Epoch 00034: val_acc did not improve from 0.64130
# Epoch 35/100
# 276/276 [==============================] - 9s 34ms/step - loss: 0.0786 - acc: 0.9855 - val_loss: 1.8216 - val_acc: 0.6304
#
# Epoch 00035: val_acc did not improve from 0.64130
# Epoch 36/100
# 276/276 [==============================] - 6s 23ms/step - loss: 0.0681 - acc: 0.9928 - val_loss: 1.8195 - val_acc: 0.6196
#
# Epoch 00036: val_acc did not improve from 0.64130
# Epoch 37/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0562 - acc: 0.9964 - val_loss: 1.8644 - val_acc: 0.6196
#
# Epoch 00037: val_acc did not improve from 0.64130
# Epoch 38/100
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0475 - acc: 1.0000 - val_loss: 1.8963 - val_acc: 0.6087
#
# Epoch 00038: val_acc did not improve from 0.64130
# Epoch 39/100
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0409 - acc: 1.0000 - val_loss: 1.9246 - val_acc: 0.6196
#
# Epoch 00039: val_acc did not improve from 0.64130
# Epoch 40/100
# 276/276 [==============================] - 5s 19ms/step - loss: 0.0349 - acc: 1.0000 - val_loss: 1.9489 - val_acc: 0.6196
#
# Epoch 00040: val_acc did not improve from 0.64130
# Epoch 41/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0302 - acc: 1.0000 - val_loss: 1.9356 - val_acc: 0.6304
#
# Epoch 00041: val_acc did not improve from 0.64130
# Epoch 42/100
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0254 - acc: 1.0000 - val_loss: 1.9993 - val_acc: 0.6196
#
# Epoch 00042: val_acc did not improve from 0.64130
# Epoch 43/100
# 276/276 [==============================] - 4s 16ms/step - loss: 0.0239 - acc: 0.9964 - val_loss: 1.9996 - val_acc: 0.6196
#
# Epoch 00043: val_acc did not improve from 0.64130
# Epoch 44/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0183 - acc: 1.0000 - val_loss: 1.9932 - val_acc: 0.6304
#
# Epoch 00044: val_acc did not improve from 0.64130
# Epoch 45/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0162 - acc: 1.0000 - val_loss: 2.0431 - val_acc: 0.6087
#
# Epoch 00045: val_acc did not improve from 0.64130
# Epoch 46/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0144 - acc: 1.0000 - val_loss: 2.0757 - val_acc: 0.6087
#
# Epoch 00046: val_acc did not improve from 0.64130
# Epoch 47/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0128 - acc: 1.0000 - val_loss: 2.0308 - val_acc: 0.6196
#
# Epoch 00047: val_acc did not improve from 0.64130
# Epoch 48/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0112 - acc: 1.0000 - val_loss: 2.0466 - val_acc: 0.6304
#
# Epoch 00048: val_acc did not improve from 0.64130
# Epoch 49/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.0095 - acc: 1.0000 - val_loss: 2.1060 - val_acc: 0.6087
#
# Epoch 00049: val_acc did not improve from 0.64130
# Epoch 50/100
# 276/276 [==============================] - 5s 17ms/step - loss: 0.0088 - acc: 1.0000 - val_loss: 2.1262 - val_acc: 0.6196
#
# Epoch 00050: val_acc did not improve from 0.64130
# Epoch 51/100
# 276/276 [==============================] - 10s 36ms/step - loss: 0.0077 - acc: 1.0000 - val_loss: 2.1165 - val_acc: 0.6087
#
# Epoch 00051: val_acc did not improve from 0.64130
# Epoch 52/100
# 276/276 [==============================] - 6s 23ms/step - loss: 0.0070 - acc: 1.0000 - val_loss: 2.1304 - val_acc: 0.6087
#
# Epoch 00052: val_acc did not improve from 0.64130
# Epoch 53/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0064 - acc: 1.0000 - val_loss: 2.1679 - val_acc: 0.6087
#
# Epoch 00053: val_acc did not improve from 0.64130
# Epoch 54/100
# 276/276 [==============================] - 3s 10ms/step - loss: 0.0059 - acc: 1.0000 - val_loss: 2.1865 - val_acc: 0.6087
#
# Epoch 00054: val_acc did not improve from 0.64130
# Epoch 55/100
# 276/276 [==============================] - 6s 20ms/step - loss: 0.0054 - acc: 1.0000 - val_loss: 2.1903 - val_acc: 0.6087
#
# Epoch 00055: val_acc did not improve from 0.64130
# Epoch 56/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0050 - acc: 1.0000 - val_loss: 2.2009 - val_acc: 0.6196
#
# Epoch 00056: val_acc did not improve from 0.64130
# Epoch 57/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0046 - acc: 1.0000 - val_loss: 2.2207 - val_acc: 0.6196
#
# Epoch 00057: val_acc did not improve from 0.64130
# Epoch 58/100
# 276/276 [==============================] - 3s 10ms/step - loss: 0.0043 - acc: 1.0000 - val_loss: 2.2372 - val_acc: 0.6196
#
# Epoch 00058: val_acc did not improve from 0.64130
# Epoch 59/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0040 - acc: 1.0000 - val_loss: 2.2409 - val_acc: 0.6196
#
# Epoch 00059: val_acc did not improve from 0.64130
# Epoch 60/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0038 - acc: 1.0000 - val_loss: 2.2469 - val_acc: 0.6196
#
# Epoch 00060: val_acc did not improve from 0.64130
# Epoch 61/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0036 - acc: 1.0000 - val_loss: 2.2579 - val_acc: 0.6196
#
# Epoch 00061: val_acc did not improve from 0.64130
# Epoch 62/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.0033 - acc: 1.0000 - val_loss: 2.2721 - val_acc: 0.6196
#
# Epoch 00062: val_acc did not improve from 0.64130
# Epoch 63/100
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0032 - acc: 1.0000 - val_loss: 2.2848 - val_acc: 0.6087
#
# Epoch 00063: val_acc did not improve from 0.64130
# Epoch 64/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.0030 - acc: 1.0000 - val_loss: 2.2938 - val_acc: 0.6196
#
# Epoch 00064: val_acc did not improve from 0.64130
# Epoch 65/100
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0028 - acc: 1.0000 - val_loss: 2.3041 - val_acc: 0.6087
#
# Epoch 00065: val_acc did not improve from 0.64130
# Epoch 66/100
# 276/276 [==============================] - 4s 16ms/step - loss: 0.0027 - acc: 1.0000 - val_loss: 2.3098 - val_acc: 0.6196
#
# Epoch 00066: val_acc did not improve from 0.64130
# Epoch 67/100
# 276/276 [==============================] - 5s 19ms/step - loss: 0.0026 - acc: 1.0000 - val_loss: 2.3189 - val_acc: 0.6087
#
# Epoch 00067: val_acc did not improve from 0.64130
# Epoch 68/100
# 276/276 [==============================] - 9s 33ms/step - loss: 0.0024 - acc: 1.0000 - val_loss: 2.3246 - val_acc: 0.6196
#
# Epoch 00068: val_acc did not improve from 0.64130
# Epoch 69/100
# 276/276 [==============================] - 6s 21ms/step - loss: 0.0023 - acc: 1.0000 - val_loss: 2.3328 - val_acc: 0.6196
#
# Epoch 00069: val_acc did not improve from 0.64130
# Epoch 70/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.0022 - acc: 1.0000 - val_loss: 2.3366 - val_acc: 0.6304
#
# Epoch 00070: val_acc did not improve from 0.64130
# Epoch 71/100
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0021 - acc: 1.0000 - val_loss: 2.3488 - val_acc: 0.6196
#
# Epoch 00071: val_acc did not improve from 0.64130
# Epoch 72/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 2.3593 - val_acc: 0.6196
#
# Epoch 00072: val_acc did not improve from 0.64130
# Epoch 73/100
# 276/276 [==============================] - 6s 21ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 2.3678 - val_acc: 0.6196
#
# Epoch 00073: val_acc did not improve from 0.64130
# Epoch 74/100
# 276/276 [==============================] - 5s 17ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 2.3770 - val_acc: 0.6196
#
# Epoch 00074: val_acc did not improve from 0.64130
# Epoch 75/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 2.3823 - val_acc: 0.6196
#
# Epoch 00075: val_acc did not improve from 0.64130
# Epoch 76/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 2.3866 - val_acc: 0.6196
#
# Epoch 00076: val_acc did not improve from 0.64130
# Epoch 77/100
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 2.3882 - val_acc: 0.6304
#
# Epoch 00077: val_acc did not improve from 0.64130
# Epoch 78/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.0016 - acc: 1.0000 - val_loss: 2.3956 - val_acc: 0.6304
#
# Epoch 00078: val_acc did not improve from 0.64130
# Epoch 79/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 2.3965 - val_acc: 0.6304
#
# Epoch 00079: val_acc did not improve from 0.64130
# Epoch 80/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 2.4072 - val_acc: 0.6304
#
# Epoch 00080: val_acc did not improve from 0.64130
# Epoch 81/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 2.4079 - val_acc: 0.6304
#
# Epoch 00081: val_acc did not improve from 0.64130
# Epoch 82/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 2.4112 - val_acc: 0.6304
#
# Epoch 00082: val_acc did not improve from 0.64130
# Epoch 83/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 2.4366 - val_acc: 0.6304
#
# Epoch 00083: val_acc did not improve from 0.64130
# Epoch 84/100
# 276/276 [==============================] - 3s 11ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 2.4455 - val_acc: 0.6304
#
# Epoch 00084: val_acc did not improve from 0.64130
# Epoch 85/100
# 276/276 [==============================] - 3s 12ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 2.4474 - val_acc: 0.6304
#
# Epoch 00085: val_acc did not improve from 0.64130
# Epoch 86/100
# 276/276 [==============================] - 4s 14ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 2.4427 - val_acc: 0.6304
#
# Epoch 00086: val_acc did not improve from 0.64130
# Epoch 87/100
# 276/276 [==============================] - 4s 15ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 2.4522 - val_acc: 0.6304
#
# Epoch 00087: val_acc did not improve from 0.64130
# Epoch 88/100
# 276/276 [==============================] - 6s 22ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 2.4678 - val_acc: 0.6304
#
# Epoch 00088: val_acc did not improve from 0.64130
# Epoch 89/100
# 276/276 [==============================] - 8s 30ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 2.4707 - val_acc: 0.6304
#
# Epoch 00089: val_acc did not improve from 0.64130
# Epoch 90/100
# 276/276 [==============================] - 6s 23ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 2.4804 - val_acc: 0.6304
#
# Epoch 00090: val_acc did not improve from 0.64130
# Epoch 91/100
# 276/276 [==============================] - 4s 13ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 2.4829 - val_acc: 0.6304
#
# Epoch 00091: val_acc did not improve from 0.64130
# Epoch 92/100
# 276/276 [==============================] - 4s 16ms/step - loss: 0.0010 - acc: 1.0000 - val_loss: 2.4872 - val_acc: 0.6304
#
# Epoch 00092: val_acc did not improve from 0.64130
# Epoch 93/100
# 276/276 [==============================] - 4s 13ms/step - loss: 9.7496e-04 - acc: 1.0000 - val_loss: 2.4966 - val_acc: 0.6304
#
# Epoch 00093: val_acc did not improve from 0.64130
# Epoch 94/100
# 276/276 [==============================] - 6s 22ms/step - loss: 9.4817e-04 - acc: 1.0000 - val_loss: 2.5048 - val_acc: 0.6304
#
# Epoch 00094: val_acc did not improve from 0.64130
# Epoch 95/100
# 276/276 [==============================] - 4s 13ms/step - loss: 9.2173e-04 - acc: 1.0000 - val_loss: 2.5134 - val_acc: 0.6304
#
# Epoch 00095: val_acc did not improve from 0.64130
# Epoch 96/100
# 276/276 [==============================] - 3s 11ms/step - loss: 8.9733e-04 - acc: 1.0000 - val_loss: 2.5198 - val_acc: 0.6304
#
# Epoch 00096: val_acc did not improve from 0.64130
# Epoch 97/100
# 276/276 [==============================] - 3s 11ms/step - loss: 8.7468e-04 - acc: 1.0000 - val_loss: 2.5229 - val_acc: 0.6304
#
# Epoch 00097: val_acc did not improve from 0.64130
# Epoch 98/100
# 276/276 [==============================] - 3s 11ms/step - loss: 8.5078e-04 - acc: 1.0000 - val_loss: 2.5318 - val_acc: 0.6304
#
# Epoch 00098: val_acc did not improve from 0.64130
# Epoch 99/100
# 276/276 [==============================] - 4s 13ms/step - loss: 8.2969e-04 - acc: 1.0000 - val_loss: 2.5364 - val_acc: 0.6304
#
# Epoch 00099: val_acc did not improve from 0.64130
# Epoch 100/100
# 276/276 [==============================] - 4s 13ms/step - loss: 8.1003e-04 - acc: 1.0000 - val_loss: 2.5415 - val_acc: 0.6304
#
# Epoch 00100: val_acc did not improve from 0.64130

# %%
######LogReg################
from sklearn.linear_model import LogisticRegression

logreg = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', LogisticRegression(n_jobs=1, C=1e5)),
               ])
logreg.fit(X_train_1, y_train)
y_pred = logreg.predict(X_test_1)

print('accuracy %s' % accuracy_score(y_pred, y_test))

accuracy_score(y_test, y_pred)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)

predictions_file = np.column_stack((X_test_1, y_pred))
print(classification_report(y_test, y_pred))
accuracy['LogReg']=accuracy_score(y_test, y_pred)

cm = confusion_matrix(y_test,y_pred)
pd.DataFrame(cm).to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//LR_confusion.csv')  


'''print(classification_report(y_test, y_pred))




pd.DataFrame(classification_report(y_test, y_pred)).to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//LR_classification.csv')  '''



labelled_data_LR=pd.DataFrame(predictions_file,columns=['Description','Label'])
labelled_data_LR.reset_index().to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//LR_results.csv')
# Out:
# accuracy 0.6392405063291139
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         3
#           1       0.42      0.38      0.40        29
#           2       0.68      0.82      0.74        87
#           3       0.75      0.53      0.62        17
#           4       0.67      0.33      0.44         6
#           5       0.43      0.27      0.33        11
#           6       1.00      1.00      1.00         5
#
# avg / total       0.62      0.64      0.62       158
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
   
#########Naive Bayes###########

nb = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB()),
              ])
nb.fit(X_train_1, y_train)


from sklearn.metrics import classification_report
y_pred = nb.predict(X_test_1)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred))
accuracy['NB']=accuracy_score(y_test, y_pred)
predictions_file = np.column_stack((X_test_1, y_pred))


cm = confusion_matrix(y_test,y_pred)
pd.DataFrame(cm).to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//NB_confusion.csv')  

labelled_data_NB=pd.DataFrame(predictions_file,columns=['Description','Label'])
labelled_data_NB.reset_index().to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//NB_results.csv')     

pd.Series(accuracy).to_csv('C://Users//rupadhyay//Desktop//Defect ML//Data//Results//Accuracy.csv')
# Out:
# accuracy 0.5443037974683544
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00         3
#           1       0.00      0.00      0.00        29
#           2       0.55      0.99      0.70        87
#           3       0.00      0.00      0.00        17
#           4       0.00      0.00      0.00         6
#           5       0.00      0.00      0.00        11
#           6       0.00      0.00      0.00         5
#
# avg / total       0.30      0.54      0.39       158
# c:\users\rupadhyay\python 3.6\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-6f3278ed23f2> in <module>()
#       6 xvalid_tfidf_ngram_chars =  tfidf_vect_ngram_chars.transform(X_test_1)
#       7
# ----> 8 clf=xgboost.XGBClassifier().fit(xtrain_tfidf_ngram_chars.tocsc(), y_train)
#       9
#      10 predictions = clf.predict(xvalid_tfidf_ngram_chars)
#
# NameError: name 'xgboost' is not defined
